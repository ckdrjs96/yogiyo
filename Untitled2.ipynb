# %%
import os, re
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from konlpy.tag import Okt
from collections import Counter

okt=Okt()

# %%
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity

# %%
PATH='/root/workspace/data/'

# %%
pre_model=Word2Vec.load(PATH+'ko.bin')

# %%
chicken=pd.read_csv(PATH+'chicken.csv', encoding='utf-8')
pizza=pd.read_csv(PATH+'pizza.csv', encoding='utf-8')
china=pd.read_csv(PATH+'china.csv', encoding='utf-8')
korea=pd.read_csv(PATH+'korea.csv', encoding='utf-8')
japan=pd.read_csv(PATH+'japan.csv', encoding='utf-8')
pig=pd.read_csv(PATH+'pig.csv', encoding='utf-8')
tteok=pd.read_csv(PATH+'tteok.csv', encoding='utf-8')
cafe=pd.read_csv(PATH+'cafe.csv', encoding='utf-8')

# %%
# stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# def make_token(review):
#     temp=re.sub("[^가-힣0-9]"," ",review)
#     temp=okt.morphs(temp, stem=True)
#     temp=[word for word in temp if not word in stopwords]
    
#     return temp

# chicken['token']=chicken.review_customer.map(lambda x: make_token(x))
# pizza['token']=pizza.review_customer.map(lambda x: make_token(x))
# china['token']=china.review_customer.map(lambda x: make_token(x))
# korea['token']=korea.review_customer.map(lambda x: make_token(x))
# japan['token']=japan.review_customer.map(lambda x: make_token(x))
# pig['token']=pig.review_customer.map(lambda x: make_token(x))
# tteok['token']=tteok.review_customer.map(lambda x: make_token(x))
# cafe['token']=cafe.review_customer.map(lambda x: make_token(x))

# %%
# all_token1=pd.concat([chicken,pizza,china])
# all_token2.to_csv(PATH+'all_token2.csv',index=False)
# del korea,japan,pig,tteok,cafe
# all_token2=pd.concat([korea,japan,pig,tteok,cafe])

# %%
all_token1=pd.read_csv(PATH+'all_token1.csv')
all_token2=pd.read_csv(PATH+'all_token2.csv')

# %%
import ast
from tqdm import tqdm

# %%
all_token1.token=all_token1.token.map(lambda x: ast.literal_eval(x))

# %%
all_token2.token=all_token2.token.map(lambda x: ast.literal_eval(x))

# %%
all_token1.token[0]
# Out:
# "['또', '순', '살', '시키다', '게', '뼈', '로', '시키다', '그래도', '맛있다']"

# %%
a=all_token1.token.values.flatten().tolist()

# %%
b=all_token2.token.values.flatten().tolist()

# %%
a_b=a+b

# %%
a_flatten=sum(a,[])

# %%
print(len(a_b), len(b))
# Out:
# 355743 196766

# %%
b_flatten=[]
for i in tqdm(range(35)):
    i=i*10000
    b_flatten+=sum(a_b[i:10000+i],[])
# Out:
# 100%|██████████| 35/35 [01:35<00:00,  2.73s/it]

# %%
b_flatten+=sum(a_b[350000:len(a_b)],[])

# %%
len(b_flatten)
# Out:
# 4107388

# %%
counter=Counter(b_flatten)

# %%
len(counter.keys())
# Out:
# 37533

# %%
threshold = 5
total_cnt = len(counter.keys()) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합


for key, value in counter.items():

    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합(vocabulary)에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 등장 빈도가 4번 이하인 희귀 단어의 수: 26421
# 단어 집합(vocabulary)에서 희귀 단어의 비율: 70.39405323315482
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 0.9580054282673075

# %%
tokenized_data=all_token1.token.values.tolist()+all_token2.token.values.tolist()

# %%
model = Word2Vec(sentences = tokenized_data, size = 100, window = 2, min_count = 5, workers = 4, sg = 1)

# %%
model.wv.__getitem__('어니언')
# Out:
# array([-0.45582926, -0.4974442 , -0.00392115,  0.36136827, -0.00413889,
#        -0.38916242, -0.76116246, -0.47198352, -0.14060664, -0.35757565,
#         0.43927255, -0.49463847,  0.13601674,  0.54748505, -0.05547973,
#        -0.17318682,  0.18390794,  0.47455207, -0.14651121, -0.05316232,
#         0.22095923, -0.5374176 , -0.14898019,  0.01605149, -0.22776416,
#        -0.14425994, -0.12018874,  0.38784623,  0.00446563, -0.15336698,
#         0.23003332,  0.00966441, -0.2182787 , -0.08929568,  0.18126804,
#         0.25238594,  0.37080023, -0.05004877, -0.34166646, -0.02958576,
#        -0.23712286,  0.55851036,  0.10558522, -0.17000224,  0.04894657,
#         0.08901779,  0.13006736,  0.24720027, -0.09828501,  0.12128738,
#         0.18939151,  0.12026536,  0.23226993, -0.5158741 , -0.3510514 ,
#         0.23753142,  0.10486021,  0.04814807, -0.26482004,  0.18042392,
#         0.6028487 ,  0.5915303 , -0.03121515,  0.1283408 , -0.35301545,
#         0.19601709, -0.05670721, -0.09689422, -0.42120934, -0.01952373,
#        -0.16133453, -0.26544896,  0.18467818, -0.09244076, -0.00515792,
#         0.13347133,  0.31195253,  0.04933657, -0.10925635,  0.4575734 ,
#        -0.29179227, -0.22113875,  0.64867496,  0.4452286 , -0.03392561,
#        -0.13018137, -0.3251591 ,  0.35061616,  0.31058097, -0.47870424,
#        -0.2586657 , -0.15237273,  0.07350789, -0.14830072, -0.02105148,
#         0.02333059, -0.30011722, -0.16590619, -0.02065895, -0.11789805],
#       dtype=float32)

# %%
model.wv.most_similar('맛있다')
# Out:
# [('멋있다', 0.7858606576919556),
#  ('맛잇엇어용', 0.7211551666259766),
#  ('맛남', 0.6892239451408386),
#  ('좋아욤', 0.6791785955429077),
#  ('흡족하다', 0.6778246164321899),
#  ('맛있엇어', 0.6776534914970398),
#  ('맛깔나다', 0.6754742860794067),
#  ('맛잇어욤', 0.6749119758605957),
#  ('맛나욤', 0.6726900935173035),
#  ('맜있어', 0.6658730506896973)]

# %%
len(tokenized_data)
# Out:
# 355743

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in tokenized_data))
print('리뷰의 최대 길이 :',min(len(l) for l in tokenized_data))

print('리뷰의 평균 길이 :',sum(map(len, tokenized_data))/len(tokenized_data))
plt.hist([len(s) for s in tokenized_data], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 207
# 리뷰의 최대 길이 : 0
# 리뷰의 평균 길이 : 11.545941873768422

# %%
catagory=pd.read_csv(PATH+'catagory_num.csv', encoding='utf-8')
cata_list=[catagory[catagory.catagory==i].shop.values.tolist() for i in range(16)]

# %%
def cluster(i):
    catagory=pd.DataFrame
    for num in cata_list[i]:
        for cata in foodlist:
            now=cata[cata.shop==num]
            if catagory.empty:
                catagory=now
            else:
                catagory=catagory.append(now)
    
    catagory.reset_index(drop=True,inplace=True)
    
    return catagory

# %%
foodlist=[all_token1,all_token2]

# %%
for i in range(0,16):
    globals()[f'catagory{i}']=cluster(i)

# %%
catagory15=cluster(15)

# %%
catagory15.shop.nunique()
# Out:
# 21

# %%
catagory15.shop.value_counts()
# Out:
# 꽃보다족발-본점             2026
# 큰맘할매순대국-배봉사거리점        936
# 닥터찬의찌개백반-전농점          555
# 봉명동내커피-경희대점           384
# 푸라닭-장안2호점             286
# 강금옥쭈꾸미                262
# 두마리찜닭두찜-동대문답십리점       255
# 아빠두리만든떡볶이-외대점         239
# 강씨네즉석떡볶이              168
# 파스타리아-전농점             115
# 지코바치킨-장안1호점           104
# 꽃보다족발-동대문점            101
# 푸라닭-답십리점               85
# 호랭이양식당                 63
# 돈갓수제돈까스-장안점            57
# 면밥                     57
# 골라먹는짱닭치킨-장안답십리점        41
# 정성간장&매운갈비찜도시락-장안점      22
# 청년불막창                   9
# 강떡                      8
# 꼬꼬누리-답심리점               4
# Name: shop, dtype: int64

# %%
cat15_shops=catagory15.shop.value_counts()[catagory15.shop.value_counts()>100].keys()

# %%
test=catagory15[catagory15.shop==cat15_shops[0]]

# %%
cat15_shops[0]
# Out:
# '꽃보다족발-본점'

# %%
test.shape
# Out:
# (2026, 11)

# %%
test_tokenized_data=test.token.values.tolist()

# %%
test_tokenized_data
# Out:
# [['소',
#   '짜다',
#   '이다',
#   '정말',
#   '푸다',
#   '짐해',
#   '요',
#   '고기',
#   '맛있다',
#   '정말',
#   '후회',
#   '없다',
#   '같이',
#   '오다',
#   '막국수',
#   '리뷰',
#   '이벤트',
#   '참여',
#   '양도',
#   '많다',
#   '무엇',
#   '보다',
#   '맛있다',
#   '배달',
#   '로',
#   '맛있다',
#   '막국수',
#   '여기',
#   '처음'],
#  ['맛있다', '먹다', '또', '먹다', '예', '용'],
#  ['오', '맛', '좋다', '젠', '고정', '주문', '처가', '생기다', '이사', '서다', '방황'],
#  ['푸다', '짐', '막국수', '랑', '족발', '자다', '먹다', '또', '시키다'],
#  ['완벽하다', '국수', '보쌈', '김치', '맛있다'],
#  ['소', '짜다', '시키다', '양', '굉장하다', '맛있다', '먹다'],
#  ['양도', '엄청', '많다', '맛', '잇다'],
#  ['가족',
#   '끼리',
#   '모',
#   '여서',
#   '처음',
#   '주문',
#   '3',
#   '인',
#   '이서',
#   '배부르다',
#   '자다',
#   '먹다',
#   '조금',
#   '남',
#   '을',
#   '정도',
#   '로',
#   '넉넉하다',
#   '양',
#   '이다',
#   '맛',
#   '만족스럽다'],
#  ['역쉬', '족발', '꽃', '막국수', '너무', '먹다', '너무', '맛', '나다'],
#  ['너무', '맛있다', '배달', '빨르다'],
#  ['양은', '약간', '적다', '구성은', '알차다', '맛', '나다', '먹다'],
#  ['막국수', '맛있다'],
#  ['맛있다', '자다', '먹다', '막국수', '넘다', '맛', '잇다'],
#  ['최애', '에고', '너무나', '맛', '나다', '냠냠', '불', '족도', '적당하다', '맵', '고', '짱', '이다'],
#  ['꾸다', '구구구구', '구'],
#  ['구성', '정말', '좋다', '다음', '에도', '시키다', '같다'],
#  ['처음', '시키다', '보다', '너무', '맛있다', '오다', '놀래다', '다', '들다', '시키다', '들다'],
#  ['매장',
#   '에서만',
#   '먹다',
#   '맛',
#   '물론',
#   '이고',
#   '배송',
#   '빠르다',
#   '리뷰',
#   '이벤트',
#   '막국수',
#   '사이즈',
#   '업다',
#   '알다',
#   '막국수',
#   '대자',
#   '하나',
#   '더',
#   '오다',
#   '맛',
#   '잇다',
#   '먹다'],
#  ['배달', '빨리', '오다', '좋다', '저', '너무', '말', '랑', '거려', '서'],
#  ['족발', '쫄깃', '하고', '맛있다'],
#  ['맛있다', '또', '시키다', '먹다'],
#  ['정말', '맛있다', '먹다'],
#  ['매번',
#   '사진',
#   '못',
#   '찍다',
#   '글',
#   '로만',
#   '올리다',
#   '족발',
#   '맛',
#   '양',
#   '그리고',
#   '김치',
#   '등등',
#   '별',
#   '5',
#   '개',
#   '아깝다',
#   '않다',
#   '조금',
#   '아쉽다',
#   '점',
#   '막국수',
#   '소스',
#   '조금',
#   '더',
#   '담다',
#   '좋다',
#   '맛',
#   '좋다',
#   '소스',
#   '약간',
#   '부족하다'],
#  ['맛', '나다', '자다', '먹다', '먹다', '못', '찍다'],
#  ['뼈', '다', '귀가', '영화', '황해', '나', '와도', '되다', '싸이', '즈', '네', '요'],
#  ['정말',
#   '다',
#   '좋다',
#   '배달',
#   '1시간',
#   '30분',
#   '걸리다',
#   '금요일',
#   '저녁',
#   '이라',
#   '그런',
#   '걸',
#   '로',
#   '알다',
#   '맛',
#   '족발',
#   '잡다',
#   '없다',
#   '너무',
#   '맛있다',
#   '쟁반',
#   '국수',
#   '너무',
#   '맛있다',
#   '먹다',
#   '배송',
#   '그러하다',
#   '그렇다',
#   '불구',
#   '하고',
#   '기꺼이',
#   '또',
#   '사먹다',
#   '구',
#   '요',
#   '번창'],
#  ['진짜',
#   '맛있다',
#   '장난',
#   '아니다',
#   '얼마나',
#   '장난',
#   '아니다',
#   '진짜',
#   '장난',
#   '아니다',
#   '꼭',
#   '먹다',
#   '불족',
#   '만세'],
#  ['맛있다', '먹다', '보쌈', '쟁반', '국수', '조합', '좋다'],
#  ['배달', '진짜', '빨르다', '양도', '많다', '고기', '맛있다', '좋다'],
#  ['양', '많다', '비빔국수', '진짜', '맛있다'],
#  ['양도',
#   '많다',
#   '맛',
#   '있다',
#   '정말',
#   '최고',
#   '에요',
#   '배달',
#   '엄청',
#   '빨르다',
#   '서비스',
#   '로',
#   '막국수',
#   '사이',
#   '즈',
#   '업',
#   '해주다',
#   '많이',
#   '먹다',
#   '많이',
#   '파다'],
#  ['보글보', '하니', '짭짤하다', '맛있다', '막국수', '맛있다', '자다', '먹다'],
#  ['배달',
#   '빠르다',
#   '양도',
#   '많다',
#   '정말',
#   '맛있다',
#   '잡다',
#   '하나',
#   '안나',
#   '고',
#   '엄청',
#   '맛있다',
#   '먹다',
#   '처음',
#   '시키다',
#   '보다',
#   '곳',
#   '인데',
#   '다음',
#   '에도',
#   '또',
#   '시키다',
#   '맛있다',
#   '자다',
#   '먹다',
#   '습',
#   '니당다'],
#  ['족발',
#   '꽃',
#   '보다',
#   '족발',
#   '제일',
#   '맛있다',
#   '족발',
#   '부드럽다',
#   '쫄깃쫄깃',
#   '하고',
#   '막국수',
#   '서비스',
#   '로',
#   '먹기',
#   '미안하다',
#   '정도',
#   '로',
#   '맛있다',
#   '오늘',
#   '자다',
#   '먹다'],
#  ['맛있다', '배달', '빠르다', '자다', '먹다'],
#  ['처음', '시키다', '보다', '존맛', '이다', '더'],
#  ['맛있다', '배추', '쌈', '쩌러', '요', '또', '먹다'],
#  ['족발', '엄청나다', '진짜', '맛있다'],
#  ['언제나', '맛', '있다'],
#  ['욕', '나오다', '정도', '로', '맛있다', '주저', '말고', '시키다', '애', '아'],
#  ['양도', '많다', '맛', '맛있다', '먹다'],
#  ['맛있다', '자다', '먹다', '다', '먹다', '사진', '을', '찍다'],
#  ['양', '많다', '맛있다'],
#  ['설레다',
#   '첫',
#   '주문',
#   '역시',
#   '서다',
#   '짜다',
#   '살이',
#   '많이',
#   '없다',
#   '후기',
#   '막국수',
#   '칭찬',
#   '이기다',
#   '먹다',
#   '보다',
#   '맛있다',
#   '괜찮다'],
#  ['배송',
#   '시간',
#   '맞추다',
#   '딱',
#   '오다',
#   '양도',
#   '많다',
#   '배',
#   '엄청',
#   '불다',
#   '맵다',
#   '맛',
#   '그렇다',
#   '많이',
#   '매다',
#   '다음',
#   '주문',
#   '땐',
#   '조금',
#   '덜맵',
#   '게',
#   '시키다',
#   '너무',
#   '맛있다'],
#  ['막국수', '진짜', '쵝오', '에요', '족발', '김치', '전부', '맛', '잇다'],
#  ['양도', '많다', '맛있다'],
#  ['양도',
#   '가격',
#   '맛',
#   '삼박자',
#   '완벽하다',
#   '맞다',
#   '성수',
#   '유명하다',
#   '족발',
#   '집',
#   '이랑',
#   '맛',
#   '비슷하다',
#   '맛맀어용'],
#  ['먹다',
#   '새벽',
#   '인데',
#   '배달',
#   '빨리',
#   '오다',
#   '주리다',
#   '배',
#   '아주',
#   '자다',
#   '채우다',
#   '불족',
#   '그렇게',
#   '맵',
#   '지는',
#   '않다',
#   '맵',
#   '찌다',
#   '자다',
#   '먹다',
#   '수',
#   '있다'],
#  ['두번째',
#   '시키다',
#   '먹다',
#   '음식',
#   '이에요',
#   '처음',
#   '엔',
#   '보쌈',
#   '시키다',
#   '먹다',
#   '이번',
#   '엔',
#   '불',
#   '족발',
#   '시키다',
#   '저',
#   '보쌈',
#   '짱',
#   '이에요',
#   '쟁반',
#   '국수',
#   '너무',
#   '맛있다'],
#  ['족발', '완전', '쪽득쫀득', '하고', '맛있다'],
#  ['진짜', '정말', '정말', '맛', '나다', '불', '족발', '불향', '지', '대로', '에요'],
#  ['양도', '많다', '맛있다'],
#  [],
#  ['자다', '먹다'],
#  ['맛', '잇다'],
#  ['맛있다', '먹다'],
#  ['매번', '족발', '여기', '에서만', '시키다', '먹다'],
#  ['힌', '동안', '문', '을', '안', '열다', '이제야', '시키다', '먹다'],
#  ['막국수', '절', '인', '배추', '싸', '먹다', '보쌈', '넘다', '맛있다', '보쌈김치', '강추'],
#  ['적당하다', '맛있다'],
#  ['맛있다', '자다', '먹다'],
#  ['굿굿굿굿굿굿굿굿굿굿굿굿'],
#  ['안녕하다', '저', '감사하다'],
#  ['공기밥', '시키다', '떡', '오다', '네오', '그거', '말고는', '다', '맛있다'],
#  ['불',
#   '족발',
#   '약간',
#   '맵다',
#   '맛',
#   '주문',
#   '역시',
#   '너무',
#   '맛있다',
#   '배달',
#   '예',
#   '정시',
#   '간',
#   '보다',
#   '빨르다',
#   '감사하다'],
#  ['맛', '잇다', '양', '많다'],
#  ['동네',
#   '에서',
#   '젤',
#   '맛',
#   '좋다',
#   '가성',
#   '비도',
#   '좋다',
#   '족발',
#   '힘드다',
#   '힐링',
#   '되다',
#   '계속',
#   '좋다',
#   '맛',
#   '가성',
#   '비',
#   '쭈욱',
#   '이다',
#   '먹다'],
#  ['맛있다',
#   '자다',
#   '먹다',
#   '적당하다',
#   '지방',
#   '반',
#   '살코기',
#   '반',
#   '포장',
#   '상태',
#   '깔끔하다',
#   '고기',
#   '방향',
#   '강하다',
#   '보쌈김치',
#   '단맛',
#   '강하다',
#   '호불호',
#   '강하다',
#   '맛',
#   '아니다',
#   '아주',
#   '깔끔하다',
#   '좋다',
#   '담',
#   '에도',
#   '생각나다',
#   '시키다',
#   '먹다',
#   '구',
#   '요'],
#  ['고', '기도', '양', '많다', '깔끔하다', '맛있다'],
#  ['맛있다', '자다', '먹다'],
#  ['맛있다', '가격', '적당', '양은', '조금', '아쉽다'],
#  ['맛있다', '먹다'],
#  ['맛있다', '다음', '애', '또', '주문'],
#  ['배달',
#   '시간',
#   '보다',
#   '20분',
#   '빨리',
#   '오다',
#   '한동안',
#   '어플',
#   '안',
#   '뜨다',
#   '먹다',
#   '싶다',
#   '꾹',
#   '참다',
#   '드디어',
#   '먹다',
#   '보쌈',
#   '을',
#   '먹다',
#   '족발',
#   '을',
#   '먹다',
#   '고민',
#   '오늘',
#   '족발',
#   '로',
#   '당첨',
#   '따뜻하다',
#   '졸깃',
#   '하',
#   '니',
#   '너무',
#   '맛있다',
#   '기다리다',
#   '보람',
#   '있다',
#   '맛있다',
#   '먹다'],
#  ['맛있다',
#   '갑자기',
#   '국수',
#   '소스',
#   '봉',
#   '다리',
#   '폭발',
#   '난리',
#   '아니다',
#   '바닥',
#   '다',
#   '쏟다',
#   '그냥',
#   '국수',
#   '되다',
#   '버리다'],
#  ['먹다', '최고', '용'],
#  ['항상', '맛있다', '먹다', '욯'],
#  ['맛있다', '먹다'],
#  ['평소', '처럼', '맛있다', '문자', '받다', '조금', '걱정스럽다'],
#  ['잡다', '맛있다', '양', '적다'],
#  ['부모님', '께서', '맛있다', '들다'],
#  ['너무', '맛있다', '꼭', '주문', '해보다'],
#  ['맛있다', '먹다'],
#  ['맛', '많이', '떨어지다', '약', '제', '더', '넣다', '동침', '마늘', '많이', '넣다', '자다', '익히다'],
#  ['양', '푸다', '짐해', '요', '먹다'],
#  ['배달', '빨랏', '고', '맛있다'],
#  ['맛', '구성', '가격', '정말', '맛있다', '끼', '이다', '감사하다'],
#  ['110분', '만에', '배달', '오다', '전화', '주다', '전화', '없다', '음식', '다', '식다'],
#  ['1234567890'],
#  ['딱', '깔끔하다', '알차다', '구성', '좋다', '막국수', '진짜', '넘다', '맛잇엇어', '요'],
#  ['가격', '대비', '너무', '저렴하다', '맛있다', '막국수', '양', '미치다'],
#  ['맛',
#   '중',
#   '중상',
#   '이다',
#   '배달',
#   '너무',
#   '늦다',
#   '너무',
#   '늦다',
#   '처음',
#   '문의',
#   '전화',
#   '때',
#   '출발',
#   '말고',
#   '첨부',
#   '터',
#   '주문',
#   '밀리다',
#   '늦다',
#   '말씀',
#   '해주다',
#   '얼마나',
#   '좋다',
#   '싶다',
#   '생각',
#   '드네',
#   '요'],
#  ['맛있다', '포장', '뜯다', '순삭', '이라', '사진', '없다', '안타깝다', '맛있다', '자다', '먹다'],
#  ['맛있다', '자다', '먹다'],
#  ['양', '적어지다'],
#  ['처음', '시키다', '보다', '구성', '좋다', '맛있다'],
#  ['배달', '맛', '정말', '좋다'],
#  ['맛',
#   '이아주',
#   '일품',
#   '이다',
#   '특대',
#   '인데',
#   '생각',
#   '보다',
#   '막',
#   '양',
#   '엄청',
#   '나다',
#   '많다',
#   '아니다'],
#  ['맛있다', '불족', '막국수'],
#  ['배달',
#   '처음',
#   '다른',
#   '주소',
#   '로',
#   '가다',
#   '당황',
#   '결국',
#   '다시',
#   '받다',
#   '자다',
#   '먹다',
#   '맛있다',
#   '먹다'],
#  ['족발', '약간', '짭쪼름한데', '맛있다', '막국수', '면', '안떡', '지게', '서다', '자다', '먹다'],
#  ['그냥',
#   '다른',
#   '말',
#   '필요없다',
#   '맛있다',
#   '양도',
#   '부족하다',
#   '않다',
#   '마스크',
#   '막국수',
#   '까지',
#   '구성',
#   '좋다',
#   '사진',
#   '을',
#   '못',
#   '찍다',
#   '죄송하다',
#   '다음',
#   '주문',
#   '때',
#   '꼭',
#   '사진',
#   '리뷰'],
#  ['몇', '일전', '먹다', '다시', '시키다', '먹다', '너무', '맛있다', '사장', '님', '자다', '묵다'],
#  ['족발',
#   '진짜',
#   '맛있다',
#   '맨날',
#   '먹다',
#   '안질리다',
#   '맛',
#   '이네',
#   '요',
#   '추천',
#   '다',
#   '들다',
#   '한번',
#   '시키다',
#   '보다'],
#  ['주말',
#   '족발',
#   '땡기다',
#   '리뷰',
#   '보고',
#   '처음',
#   '주문',
#   '보들보들',
#   '맛있다',
#   '아이',
#   '자다',
#   '먹다',
#   '또',
#   '주문',
#   '수고'],
#  ['진짜',
#   '오랜',
#   '만',
#   '시키다',
#   '먹다',
#   '더',
#   '맛있다',
#   '같다',
#   '쫄깃',
#   '하고',
#   '맛있다',
#   '먹다',
#   '습',
#   '니당다'],
#  ['왜',
#   '리뷰',
#   '많다',
#   '알다',
#   '구',
#   '성',
#   '딱',
#   '좋다',
#   '버리다',
#   '없다',
#   '특히',
#   '불',
#   '족발',
#   '맵다',
#   '계속',
#   '땡기다',
#   '멈추다',
#   '업다',
#   '계속',
#   '이렇게',
#   '보내다'],
#  ['고기',
#   '퍽퍽',
#   '하고',
#   '족발',
#   '양념',
#   '짜다',
#   '막국수',
#   '괜찮다',
#   '생각나다',
#   '맛',
#   '아니다',
#   '배달',
#   '오다',
#   '쏠리다',
#   '국물',
#   '다',
#   '세고',
#   '여러',
#   '모로',
#   '별',
#   '루',
#   '이다'],
#  ['족발', '맛있다', '막국수', '맛있다'],
#  ['항상',
#   '족발',
#   '보쌈',
#   '세트',
#   '정말',
#   '맛있다',
#   '먹다',
#   '이번',
#   '엔',
#   '특별하다',
#   '맛',
#   '평소',
#   '랑',
#   '다르다',
#   '특히',
#   '보쌈',
#   '맛',
#   '이번',
#   '저번',
#   '약간',
#   '실망',
#   '스럽다',
#   '원래',
#   '정말',
#   '맛있다',
#   '말',
#   '죠',
#   '다음',
#   '번',
#   '주문',
#   '에는',
#   '기대',
#   '해보다'],
#  ['맨날',
#   '족발',
#   '만',
#   '시키다',
#   '먹다',
#   '보쌈',
#   '첨으로',
#   '시키다',
#   '먹다',
#   '보쌈',
#   '맛있다',
#   '항상',
#   '기대',
#   '이상',
#   '맛있다'],
#  ['단골',
#   '이다',
#   '늘',
#   '맛있다',
#   '양도',
#   '많다',
#   '배달',
#   '시간',
#   '내',
#   '자다',
#   '오다',
#   '자다',
#   '먹다',
#   '감사하다',
#   '늘',
#   '건강하다'],
#  ['배달',
#   '빠르다',
#   '양도',
#   '푸다',
#   '짐해',
#   '요',
#   '4',
#   '명',
#   '식사',
#   '꽤',
#   '남다',
#   '맛있다',
#   '자다',
#   '먹다',
#   '사장',
#   '님',
#   '감사하다'],
#  ['짱', '이에요', '맛있다', '굿굿'],
#  ['배송',
#   '너무',
#   '빠르다',
#   '양도',
#   '많다',
#   '막국수',
#   '늠',
#   '나',
#   '맛있다',
#   '족발',
#   '늠',
#   '나',
#   '맛있다',
#   '족발',
#   '막국수',
#   '얹다',
#   '묵다',
#   '제발',
#   '너무',
#   '맛있다',
#   '진심',
#   '먹다'],
#  ['족발',
#   '여기',
#   '서',
#   '만',
#   '시키다',
#   '먹다',
#   '사진',
#   '찍',
#   '을',
#   '생각',
#   '못',
#   '하고',
#   '흡입',
#   '양도',
#   '많다',
#   '고기',
#   '퀄리티',
#   '굳이',
#   '에요'],
#  ['족발',
#   '진짜',
#   '엄청',
#   '맛있다',
#   '추천',
#   '다',
#   '들다',
#   '한번',
#   '시키다',
#   '보다',
#   '후회',
#   '없다',
#   '맛',
#   '이다'],
#  ['처음',
#   '시키다',
#   '보다',
#   '진짜',
#   '맛있다',
#   '족발',
#   '쟁반',
#   '국수',
#   '싸',
#   '먹다',
#   '너무',
#   '맛있다',
#   '불',
#   '족발',
#   '쫀득',
#   '하고',
#   '적당하다',
#   '맵다',
#   '손',
#   '계속',
#   '가다',
#   '맛',
#   '이에요',
#   '배달',
#   '빨르다'],
#  ['족발', '먹다', '때', '주문', '늘', '먹다', '맛', '이네', '용'],
#  ['족발',
#   '완전',
#   '맛있다',
#   '제',
#   '먹기',
#   '에는',
#   '양',
#   '많다',
#   '쟁반',
#   '막국수',
#   '절반',
#   '넘다',
#   '남기다'],
#  ['맛있다', '써다', '배달', '빨르다'],
#  ['그냥', '그럭저럭', '배고프다', '때', '먹다', '제일', '맛있다'],
#  ['족발',
#   '양은',
#   '두',
#   '명',
#   '먹기',
#   '충분하다',
#   '근데',
#   '먹다',
#   '양',
#   '많다',
#   '분',
#   '모자',
#   '것',
#   '같다',
#   '쟁반',
#   '국수',
#   '정말',
#   '너무',
#   '먹다',
#   '싶다',
#   '시키다',
#   '아쉽다',
#   '제',
#   '입맛',
#   '에는',
#   '안',
#   '맞다',
#   '와사비',
#   '맛',
#   '너무',
#   '나',
#   '것',
#   '같다',
#   '그리고',
#   '족발',
#   '껍데기',
#   '부분',
#   '괜찮다',
#   '고기',
#   '부분',
#   '에서',
#   '쪼금',
#   '냄새',
#   '나',
#   '부분',
#   '있다',
#   '제',
#   '예민하다',
#   '한데',
#   '같이',
#   '먹다',
#   '사람',
#   '조금',
#   '냄새',
#   '나다',
#   '그래도',
#   '감사히',
#   '자다',
#   '먹다'],
#  ['양도', '많다', '맛있다', '먹다', '다음', '또', '시키다'],
#  ['리뷰',
#   '써다',
#   '배달',
#   '너무',
#   '빨리',
#   '오다',
#   '30분',
#   '을',
#   '넘다',
#   '기다리다',
#   '예전',
#   '부터',
#   '꾸준하다',
#   '먹다',
#   '곳',
#   '이에요',
#   '여전하다',
#   '맛',
#   '나',
#   '요',
#   '양도',
#   '넘다',
#   '많다',
#   '남녀',
#   '둘',
#   '소자',
#   '막국수',
#   '사이즈',
#   '업',
#   '시키다',
#   '배',
#   '터지다',
#   '양',
#   '남다',
#   '여자',
#   '양은',
#   '평균',
#   '남자',
#   '많이',
#   '먹다',
#   '펴다',
#   '그렇다',
#   '또',
#   '시키다'],
#  ['매콤', '하고', '외다', '맛있다'],
#  ['가격',
#   '착하다',
#   '양',
#   '적다',
#   '알다',
#   '완전',
#   '많다',
#   '족발',
#   '너무',
#   '맛있다',
#   '앞',
#   '족발',
#   '여기',
#   '서',
#   '시키다',
#   '먹다'],
#  ['양도', '많다', '맛있다', '매번', '시키다', '먹다', '이유', '있다'],
#  ['개꿀맛', '예요', '또', '시키다', '먹다'],
#  ['먹다',
#   '곳',
#   '문',
#   '닫다',
#   '시키다',
#   '존맛',
#   '이제',
#   '여기',
#   '로',
#   '갈아타다',
#   '쟁반',
#   '국수',
#   '리뷰',
#   '이벤트',
#   '로',
#   '사이즈',
#   '업',
#   '완전',
#   '크다',
#   '불',
#   '족도',
#   '적당하다',
#   '매콤',
#   '다른',
#   '데',
#   '너무',
#   '맵다',
#   '화가',
#   '날',
#   '정도',
#   '이다',
#   '딱',
#   '좋다',
#   '배달',
#   '시간',
#   '예상',
#   '보다',
#   '10분',
#   '일찍',
#   '오다',
#   '맛있다',
#   '굿굿'],
#  ['배달',
#   '빠르다',
#   '배달',
#   '분도',
#   '친절',
#   '깔끔하다',
#   '포장',
#   '마스크',
#   '까지',
#   '감동',
#   '인데',
#   '넘다',
#   '넘다',
#   '부드럽다',
#   '맛있다',
#   '아',
#   '주',
#   '기분',
#   '좋다',
#   '먹다',
#   '코로나',
#   '로',
#   '힘들다',
#   '홧팅',
#   '번창'],
#  ['맛있다', '양도', '많다'],
#  ['시키다', '때', '마다', '진짜', '먹다', '맛있다', '먹다'],
#  ['맛있다'],
#  ['너무', '맛있다', '또', '시키다'],
#  ['처음', '시키다', '부드럽다', '맛있다', '불', '족발', '신라면', '보단', '매운정도', '같다', '먹다'],
#  ['배달', '빠르다', '양도', '적당하다', '맛', '적당하다', '좋다'],
#  ['족발', '을', '가격', '푸다', '짐', '양', '을', '주다', '맛있다', '먹다'],
#  ['맛', '잇다', '자다', '먹엇습니', '다'],
#  ['오', '존맛', '탱', '절', '인', '배추', '싸', '먹다', '정말', '맛있다', '강추'],
#  ['먹다'],
#  ['막국수', '정말', '맛있다'],
#  ['소', '짜다', '리도', '둘이서', '먹기', '양', '많다', '내일', '먹다', '구', '요', '먹다'],
#  ['자다', '먹다'],
#  ['존맛',
#   '이에요',
#   '저번',
#   '시키다',
#   '너무',
#   '맛있다',
#   '또',
#   '시키다',
#   '양도',
#   '많다',
#   '남기다',
#   '습',
#   '니당다',
#   '나중',
#   '또',
#   '시키다',
#   '먹다',
#   '용'],
#  ['서비스', '막국수', '감사하다', '항상', '먹다', '있다'],
#  ['포장',
#   '꼼꼼하다',
#   '깔끔하다',
#   '자다',
#   '받다',
#   '양',
#   '너무',
#   '많다',
#   '셋',
#   '이서',
#   '먹다',
#   '많이',
#   '남기다',
#   '너무',
#   '맛있다',
#   '자다',
#   '먹다',
#   '감사하다'],
#  ['맛있다', '양도', '푸다', '짐'],
#  ['집',
#   '가깝다',
#   '배달',
#   '빠르다',
#   '언제나',
#   '변하다',
#   '없다',
#   '맛',
#   '족발',
#   '꽃',
#   '보다',
#   '족발',
#   '1',
#   '순위',
#   '이다',
#   '족발',
#   '양도',
#   '많다',
#   '쫄깃쫄깃해',
#   '요',
#   '겉절이',
#   '서비스',
#   '로',
#   '주시',
#   '막국수',
#   '진짜',
#   '맛있다',
#   '오늘',
#   '맛있다',
#   '자다',
#   '먹다'],
#  ['배달', '빠르다', '막국수', '양', '무지', '많다', '배', '터지다', '먹다'],
#  ['받다'],
#  ['마스크', '감사하다', '냉채', '족발', '맛있다'],
#  ['맛있다',
#   '먹다',
#   '카드',
#   '결제',
#   '라고',
#   '카드',
#   '기',
#   '고장',
#   '나다',
#   '현금',
#   '달라',
#   '건',
#   '잔돈',
#   '없다',
#   '잔돈',
#   '맞추다',
#   '달라',
#   '니요',
#   '배달'],
#  ['보쌈', '진짜', '냄새', '안나', '고', '맛있다', '엄지', '척'],
#  ['보통', '이상', '맛', '먹다'],
#  ['양도', '적당하다', '맛', '좋다', '상추', '싱싱하다', '좋다'],
#  ['족발',
#   '진짜',
#   '너무',
#   '맛있다',
#   '사장',
#   '님',
#   '엄청',
#   '신경',
#   '쓸다',
#   '매번',
#   '변하다',
#   '않다',
#   '챙기다',
#   '들다',
#   '정말',
#   '깔끔하다',
#   '질',
#   '양',
#   '맛',
#   '전부',
#   '최고',
#   '에요',
#   '그리다',
#   '같이',
#   '오다',
#   '막국수',
#   '진짜',
#   '면빨',
#   '이나',
#   '소스',
#   '진짜',
#   '여기',
#   '보다',
#   '맛있다',
#   '곳',
#   '없다',
#   '여기',
#   '사장',
#   '님',
#   '진짜',
#   '엄청',
#   '예리하다',
#   '신분'],
#  ['맛있다', '자다', '먹다'],
#  ['냉채', '족발', '정말', '맛있다', '야채', '푸다', '지다'],
#  ['불족', '보쌈', '음', '처음', '이다', '맛있다', '자다', '먹다'],
#  ['맛',
#   '좋다',
#   '양도',
#   '많다',
#   '가격',
#   '좋다',
#   '먹다',
#   '세',
#   '심하다',
#   '마스크',
#   '까지',
#   '챙기다',
#   '감사하다'],
#  ['사진',
#   '을',
#   '지우다',
#   '버리다',
#   '서비스',
#   '막국수',
#   '너무',
#   '자다',
#   '먹다',
#   '족발',
#   '먹다',
#   '때',
#   '마다',
#   '여기',
#   '서',
#   '자다',
#   '먹다',
#   '있다'],
#  ['맛있다'],
#  ['고기',
#   '누리다',
#   '전혀',
#   '안나',
#   '서',
#   '맛',
#   '있다',
#   '뼈',
#   '다',
#   '귀',
#   '너무',
#   '커서',
#   '그렇다',
#   '양',
#   '적다',
#   '듯',
#   '불족',
#   '불맛나',
#   '맵다',
#   '맛',
#   '아니다',
#   '제육',
#   '양념',
#   '맛',
#   '나서다',
#   '살짝',
#   '아쉽다'],
#  ['너무', '맛있다', '자다', '먹다'],
#  ['맛있다', '음식', '먹다', '양도', '적당하다', '배달', '빨르다'],
#  ['맛있다', '양도', '많다', '배달', '빨리', '해주다', '따뜻하다', '먹다'],
#  ['양', '믾아', '서', '좋다'],
#  ['항상', '맛있다', '자다', '먹다', '있다'],
#  ['역시',
#   '꽃족',
#   '족발',
#   '너무',
#   '맛있다',
#   '늦다',
#   '저녁',
#   '인데',
#   '쫄깃탱글',
#   '고기',
#   '굳다',
#   '폭',
#   '식',
#   '맛있다',
#   '음식',
#   '감사하다'],
#  ['족발',
#   '진짜',
#   '맛있다',
#   '진짜',
#   '너무',
#   '너무',
#   '맛있다',
#   '항상',
#   '자다',
#   '먹다',
#   '다음',
#   '또',
#   '주문'],
#  ['인간',
#   '적',
#   '비계',
#   '많다',
#   '다리다',
#   '상품',
#   '쓰다',
#   '맙시',
#   '다',
#   '고기',
#   '먹다',
#   '시키다',
#   '비계',
#   '먹다',
#   '건',
#   '아니다',
#   '그리고',
#   '보통',
#   '돼지',
#   '에게',
#   '과도',
#   '비계',
#   '있다',
#   '족발',
#   '문제',
#   '있다',
#   '아니다',
#   '일',
#   '반',
#   '돼지',
#   '기르다',
#   '있다',
#   '다리다',
#   '품종',
#   '공급',
#   '처가',
#   '의심스럽다'],
#  ['배', '고프다', '다', '먹다', '사진', '없다', '하지만', '맛있다', '꼭', '주문'],
#  ['늘',
#   '맛있다',
#   '오늘',
#   '더',
#   '특히',
#   '매우',
#   '맛있다',
#   '쫀득쪽득',
#   '스르르',
#   '녹다',
#   '족발',
#   '막국수',
#   '맛있다',
#   '감사하다',
#   '마스크',
#   '감사하다',
#   '늘',
#   '건강하다'],
#  ['후기',
#   '평이',
#   '좋다',
#   '처음',
#   '주문',
#   '해봤다',
#   '괜찮다',
#   '제입',
#   '엔',
#   '약간',
#   '짜다',
#   '같다',
#   '고기',
#   '부드럽다',
#   '쫄깃',
#   '초딩',
#   '2',
#   '4',
#   '식구',
#   '대자',
#   '딱',
#   '맞다'],
#  ['맛', '나', '요', '열', '글자'],
#  ['맛있다', '흡수', '버리다'],
#  ['여러', '번', '먹다', '맛', '변하다', '없이', '맛있다'],
#  ['족발', '차다', '맛있다', '사업', '번창'],
#  ['너무', '많다', '타', '자다', '먹다'],
#  ['여기', '맛있다', '먹다'],
#  ['저렴하다', '양', '많다', '맛있다', '두번째', '에요'],
#  ['양도',
#   '진짜',
#   '많다',
#   '배달',
#   '예상',
#   '시간',
#   '보다',
#   '훨씬',
#   '일찍',
#   '오다',
#   '맛있다',
#   '자다',
#   '먹다',
#   '습',
#   '니당다'],
#  ['배달',
#   '시간',
#   '보다',
#   '20분',
#   '이나',
#   '빨리',
#   '오다',
#   '요청',
#   '사항',
#   '남기다',
#   '막국수',
#   '쟁반',
#   '막국수',
#   '크기',
#   '로',
#   '오다',
#   '족발',
#   '보들보들',
#   '해',
#   '요',
#   '단맛',
#   '족발',
#   '이다',
#   '살짝',
#   '짧다',
#   '짜다',
#   '담백하다',
#   '맛',
#   '예요',
#   '불',
#   '족발',
#   '맵달',
#   '로',
#   '딱이다'],
#  ['배달',
#   '삼십분',
#   '만에',
#   '오다',
#   '너무',
#   '좋다',
#   '배달',
#   '해주다',
#   '분도',
#   '친절하다',
#   '더',
#   '좋다',
#   '역시',
#   '나',
#   '맛',
#   '있다',
#   '막국수',
#   '많다',
#   '너무',
#   '좋다',
#   '다',
#   '맛있다',
#   '족발',
#   '쫄깃해',
#   '서',
#   '식',
#   '감다',
#   '좋다',
#   '오랜',
#   '만',
#   '족발',
#   '먹다',
#   '같이',
#   '먹다',
#   '분도',
#   '진짜',
#   '자다',
#   '들다',
#   '족발',
#   '집다',
#   '꽃족',
#   '정',
#   '전',
#   '엔',
#   '포장',
#   '문',
#   '제거',
#   '있다',
#   '이번',
#   '에는',
#   '없다',
#   '보내다',
#   '또',
#   '만족하다'],
#  ['구성', '마음', '들다', '맛있다'],
#  ['맛있다', '보다', '먹다'],
#  ['맛있다',
#   '정말',
#   '먹다',
#   '후다닥',
#   '찍다',
#   '족발',
#   '포실포실',
#   '하니',
#   '맛있다',
#   '막국수',
#   '맛',
#   '나다',
#   '보쌈',
#   '맛',
#   '난',
#   '데',
#   '저',
#   '개다',
#   '꽃',
#   '보다',
#   '족발',
#   '이라고',
#   '이름',
#   '지다',
#   '신다',
#   '아니다',
#   '낭',
#   '남편',
#   '맛',
#   '나',
#   '대요',
#   '나중',
#   '또',
#   '시키다',
#   '먹다',
#   '욤'],
#  ['맛있다', '배송', '빨르다'],
#  ['맛있다', '자다', '먹다'],
#  ['육즙',
#   '살다',
#   '보들보들하다',
#   '부드럽다',
#   '상추',
#   '두',
#   '싱싱하다',
#   '음식',
#   '신선하다',
#   '정성',
#   '느껴지다',
#   '좋다'],
#  ['맛있다', '최고', '에요'],
#  ['막국수', '너무', '맛있다', '다음', '또', '시키다', '먹다'],
#  ['지난',
#   '번',
#   '에는',
#   '워낙',
#   '맛있다',
#   '이번',
#   '에는',
#   '기대',
#   '많이',
#   '해',
#   '서',
#   '그렇다',
#   '아쉽다',
#   '그래도',
#   '자다',
#   '먹다'],
#  ['양', '적다', '맛있다'],
#  ['족발', '촉촉하다', '없다', '막국수', '맛있다'],
#  ['완전', '맛있다'],
#  ['역시', '맛있다', '다른', '족발', '못', '먹다', '양', '너무', '많다', '다음', '엔', '작다', '시키다'],
#  ['역대', '급', '맛있다'],
#  ['맛있다', '먹다', '나중', '또', '주문'],
#  ['다른', '족발', '집', '에서는', '못', '시키다', '먹다', '집맛', '족발', '마스크', '센스'],
#  ['맛있다', '자주', '시키다', '먹다', '되다'],
#  ['배달', '조금', '늦다', '맛있다'],
#  ['짜다', '나쁘다', '않다'],
#  ['양', '많다', '배달', '빠르다', '맛', '나쁘다', '않다'],
#  ['맛있다', '먹다'],
#  ['여윽시', '내', '단골', '집', '꽃', '보다', '족발', '짱', '이다'],
#  ['맛있다', '먹다', '양도', '많다', '매번', '만족하다'],
#  ['양도', '무지', '많다', '맛', '괜찮다', '암튼', '전체', '적', '좋다', '음', '요'],
#  ['푸다', '짐', '하고', '맛있다'],
#  ['이사',
#   '서다',
#   '리뷰',
#   '찾아보다',
#   '주문',
#   '맛있다',
#   '배달',
#   '깔끔하다',
#   '자다',
#   '오다',
#   '막국수',
#   '너무',
#   '맛있다',
#   '근데',
#   '족발',
#   '양은',
#   '생각',
#   '보다',
#   '쫌',
#   '적다',
#   '같다'],
#  ['맛있다', '족발', '보쌈', '머', '하나', '맛없다', '없다'],
#  ['오랜', '만', '시키다', '먹다', '역시', '맛있다', '담', '또', '먹다'],
#  ['매번',
#   '먹다',
#   '곳',
#   '똑같다',
#   '먹다',
#   '먹다',
#   '항상',
#   '자다',
#   '먹다',
#   '습',
#   '니',
#   '닷',
#   '마늘',
#   '소스',
#   '진짜',
#   '기',
#   '대안',
#   '하고',
#   '먹다',
#   '뭐',
#   '죠',
#   '너무',
#   '맛있다',
#   '먹다',
#   '그리고',
#   '막국수',
#   '하앍',
#   '대박',
#   '진짜',
#   '너무',
#   '감사하다',
#   '먹다',
#   '감사하다',
#   '다음',
#   '에도',
#   '무조건',
#   '한번',
#   '더',
#   '시키다',
#   '먹다'],
#  ['꽃족',
#   '불족',
#   '중독',
#   '에여',
#   '맛있다',
#   '매콤',
#   '서고',
#   '계속',
#   '먹다',
#   '요',
#   '오늘',
#   '폭',
#   '식',
#   '맛있다',
#   '음식',
#   '감사하다'],
#  ['항상', '맛', '잇다', '자다', '먹다', '동네', '에서는', '여기', '만', '곳', '없다', '감사하다'],
#  ['족발',
#   '진짜',
#   '엄청',
#   '맛있다',
#   '다',
#   '들다',
#   '시키다',
#   '먹다',
#   '보다',
#   '원래',
#   '이렇다',
#   '쓰다',
#   '여기다',
#   '진짜',
#   '강추'],
#  ['족발',
#   '에서',
#   '누리다',
#   '비슷하다',
#   '냄새',
#   '나서다',
#   '먹다',
#   '못',
#   '먹다',
#   '방향',
#   '많이',
#   '배다',
#   '부분',
#   '괜찮다',
#   '거의',
#   '다',
#   '누리다',
#   '나다'],
#  ['배달',
#   '빨르다',
#   '양도',
#   '많다',
#   '맛',
#   '있다',
#   '무엇',
#   '보다',
#   '김치',
#   '너무',
#   '맛있다',
#   '김치',
#   '맛있다',
#   '맛집',
#   '아니다',
#   '족발',
#   '시키다',
#   '때',
#   '또',
#   '여기',
#   '서',
#   '시키다'],
#  ['맛있다', '양도', '많다', '마스크', '주다', '감사하다'],
#  ['족발',
#   '너무',
#   '맛있다',
#   '꼬들꼬들하다',
#   '양도',
#   '많다',
#   '거기',
#   '다가',
#   '막국수',
#   '까지',
#   '너무',
#   '맛있다'],
#  ['맛있다', '먹다', '배달', '빠르다'],
#  ['순',
#   '살불',
#   '족발',
#   '너무',
#   '맛있다',
#   '사다',
#   '찍다',
#   '죄송하다',
#   '작다',
#   '시키다',
#   '족발',
#   '양',
#   '충분하다',
#   '순',
#   '살',
#   '족발',
#   '소자',
#   '적',
#   '은감',
#   '잇다',
#   '껍데기',
#   '쪽',
#   '많다',
#   '맛',
#   '최고'],
#  ['배달', '정확하다', '족발', '맛있다'],
#  ['배달', '빠르다', '맛', '짱'],
#  ['배달', '빠르다', '맛', '아주', '훌륭하다', '막국수', '사이', '즈', '업', '엄청', '많다'],
#  ['정알', '맛있다', '양도', '푸다', '지다'],
#  ['먹다',
#   '족발',
#   '조금',
#   '짜다',
#   '부분',
#   '있다',
#   '먹다',
#   '지장',
#   '없다',
#   '족발',
#   '크다',
#   '뼈',
#   '안',
#   '주다',
#   '되다',
#   '것',
#   '같다'],
#  ['너무',
#   '맛있다',
#   '배달',
#   '빠르다',
#   '요청',
#   '사항',
#   '뼈',
#   '빼',
#   '달라',
#   '고',
#   '다음',
#   '에는',
#   '꼭',
#   '빼다'],
#  ['처음',
#   '시키다',
#   '먹다',
#   '보다',
#   '예상외',
#   '로',
#   '너무',
#   '먹다',
#   '가성',
#   '비',
#   '마스크',
#   '까지',
#   '보내다',
#   '셧',
#   '늘다',
#   '배고프다',
#   '허겁지겁',
#   '먹다',
#   '미처',
#   '사진',
#   '을',
#   '못',
#   '찍다',
#   '네',
#   '용',
#   '다음',
#   '에는',
#   '무조건',
#   '사진',
#   '찍다',
#   '올리다',
#   '사장',
#   '님',
#   '맞다',
#   '따다',
#   '써비',
#   '스',
#   '로',
#   '주신',
#   '막국수',
#   '까지',
#   '쫀맛탱',
#   '알',
#   '먹다',
#   '습',
#   '니',
#   '닸',
#   '코로나',
#   '때문',
#   '힘들다',
#   '항상',
#   '힘내다',
#   '화이팅',
#   '3'],
#  ['족발',
#   '진짜',
#   '맛있다',
#   '오늘',
#   '은유',
#   '달리',
#   '더',
#   '맛있다',
#   '같다',
#   '자주',
#   '시키다',
#   '먹다',
#   '리뷰',
#   '이벤트',
#   '막국수',
#   '양도',
#   '많다',
#   '맛있다',
#   '감사하다'],
#  ['고',
#   '기',
#   '맛',
#   '좋다',
#   '위생',
#   '상태',
#   '배달',
#   '서비스',
#   '미흡하다',
#   '느낌',
#   '다른',
#   '음식',
#   '이다',
#   '안',
#   '보이다',
#   '하필',
#   '마늘',
#   '붙다',
#   '사진',
#   '랩',
#   '안',
#   '벗기다',
#   '상태',
#   '이다'],
#  ['맛있다', '주문', '먹다'],
#  ['푸다', '짐', '하고', '맛있다', '자다', '먹다'],
#  ['처음',
#   '시키다',
#   '생각',
#   '더더',
#   '더',
#   '만족',
#   '보쌈',
#   '냄새',
#   '안나',
#   '고',
#   '부드럽다',
#   '너무',
#   '너무',
#   '맛있다',
#   '마늘',
#   '소스',
#   '완전',
#   '대박',
#   '직접',
#   '만들다',
#   '건지다',
#   '너무',
#   '알차다',
#   '막국수',
#   '소스',
#   '많다',
#   '자다',
#   '비비다',
#   '너무',
#   '좋다',
#   '새',
#   '콤',
#   '하',
#   '니',
#   '느끼하다',
#   '않다',
#   '보쌈',
#   '고기',
#   '질리',
#   '지',
#   '않다',
#   '다',
#   '먹다'],
#  ['양도', '많다', '맛있다', '먹다'],
#  ['족발', '맛있다', '먹다', '보쌈', '아무래도', '배달', '보단', '직접', '가다', '먹다', '더', '맛있다'],
#  ['불',
#   '족발',
#   '이렇게',
#   '맛있다',
#   '곳',
#   '처음',
#   '먹다',
#   '보다',
#   '직화',
#   '불',
#   '족발',
#   '진짜',
#   '맛있다',
#   '맛있다',
#   '맵다',
#   '맛',
#   '정말',
#   '좋다'],
#  ['여기다', '믿다', '먹다', '곳', '어제', '살코기', '부위', '부탁', '맛있다', '먹다'],
#  ['간단하다', '끼', '슥', '때우다', '너무', '좋다', '주저', '시키다', '들다'],
#  ['신랑',
#   '저',
#   '때문',
#   '족발',
#   '살짝',
#   '지겹다',
#   '근데',
#   '맛있다',
#   '어째',
#   '요',
#   '먹다',
#   '먹다',
#   '쥬',
#   '먹다'],
#  ['막국수', '맛있다'],
#  ['불',
#   '족발',
#   '시키다',
#   '너무',
#   '맛있다',
#   '막국수',
#   '김치',
#   '까지',
#   '다',
#   '만족스럽다',
#   '습',
#   '니당다',
#   '다음',
#   '또',
#   '먹다',
#   '싳',
#   '어',
#   '요'],
#  ['역시', '평소', '대로', '맛있다', '깔끔하다', '자다', '먹다'],
#  ['냠냠', '냠냠', '냠냠', '냥', '냠냠', '냠'],
#  ['너무',
#   '맛있다',
#   '아시',
#   '죠',
#   '김장',
#   '김치',
#   '때',
#   '그',
#   '넉',
#   '낌',
#   '다가',
#   '쟁반',
#   '막국수',
#   '약간',
#   '냉면',
#   '느낌',
#   '나서다',
#   '제',
#   '스탈',
#   '아니다',
#   '배추',
#   '쌈',
#   '이랑',
#   '김치',
#   '무',
#   '말랭이',
#   '로',
#   '그냥',
#   '사르르',
#   '르르',
#   '마스크',
#   '까지',
#   '오다',
#   '깜짝',
#   '놀래다',
#   '진짜',
#   '두',
#   '번시',
#   '켜',
#   '들다'],
#  ['예정', '보다', '빨리', '오다', '요청', '자다', '반영', '돼다'],
#  ['첨', '시키다', '보다', '맛있다'],
#  ['양도', '많다', '맛있다', '다음', '또', '시키다'],
#  ['일주일', '사이', '두', '번', '시키다', '먹음'],
#  ['빠르다',
#   '배달',
#   '감사하다',
#   '족발',
#   '맛있다',
#   '오늘',
#   '막국수',
#   '땡기다',
#   '기',
#   '본',
#   '외',
#   '추가',
#   '흡입'],
#  ['늘',
#   '믿다',
#   '먹다',
#   '여기저기',
#   '먹다',
#   '보다',
#   '꽃족',
#   '만',
#   '곳',
#   '없다',
#   '오늘',
#   '맛있다',
#   '먹다',
#   '서비스',
#   '감사하다'],
#  ['항상',
#   '맛',
#   '잇다',
#   '먹다',
#   '감사하다',
#   '또',
#   '시키다',
#   '먹다',
#   '맛',
#   '이에요',
#   '양도',
#   '많다',
#   '맛',
#   '좋다'],
#  ['맛있다', '살짝', '아쉽다'],
#  ['작다',
#   '주문',
#   '뼈',
#   '만',
#   '대다',
#   '짜다',
#   '이다',
#   '남',
#   '들다',
#   '뼈',
#   '만',
#   '추가',
#   '보내다',
#   '상추',
#   '끝',
#   '다',
#   '썩다',
#   '못',
#   '먹다',
#   '버리다'],
#  ['처음',
#   '주문',
#   '성공하다',
#   '쫀득',
#   '식감',
#   '족발',
#   '이네',
#   '요',
#   '맛있다',
#   '자다',
#   '먹음',
#   '요',
#   '근데',
#   '막국수',
#   '쏘다',
#   '쏘다',
#   '제',
#   '입맛',
#   '에요'],
#  ['냉채', '족발', '소스', '맛', '너', '뮤', '약하다'],
#  ['괜찮다', '나쁘다', '않다'],
#  ['매번', '맛있다', '자다', '먹다', '있다'],
#  ['사', '알짝', '식다', '맛있다', '먹다', '따뚯', '사장', '님', '맘씨'],
#  ['배달', '진짜', '빨', '라서', '놀래다', '고기', '야들야들하다', '지방도', '적다', '아주', '맛있다'],
#  ['배달', '엄청', '빨리', '오다', '맛있다', '먹다'],
#  ['사진',
#   '비록',
#   '없다',
#   '너무',
#   '너무',
#   '맛있다',
#   '특히',
#   '막국수',
#   '랑',
#   '보쌈',
#   '진짜',
#   '짱',
#   '이다',
#   '족발',
#   '생각',
#   '보다',
#   '짜다',
#   '약간',
#   '먹기',
#   '그래도',
#   '맛있다',
#   '먹다'],
#  ['너무', '맛있다'],
#  ['족발', '잘먹엇슘다', '아'],
#  ['맛있다', '족발', '이랑', '불족', '반', '반'],
#  ['양', '많다', '배달', '빨리', '오다', '좋다'],
#  ['정말', '맛있다', '잘먹엇습니', '다'],
#  ['맛있다', '다음', '또'],
#  ['그냥', '보통', '족발', '맛'],
#  ['여기다', '말', '필요없다'],
#  ['음식',
#   '양도',
#   '많다',
#   '맛있다',
#   '근데',
#   '비다',
#   '서',
#   '그런',
#   '지',
#   '배달',
#   '조금',
#   '늦다',
#   '오다',
#   '구',
#   '용',
#   '그것',
#   '말고는',
#   '또',
#   '시키다',
#   '먹다',
#   '의향',
#   '있다'],
#  ['고기',
#   '잡다',
#   '안나',
#   '고',
#   '너무',
#   '맛있다',
#   '허겁지겁',
#   '먹다',
#   '사진',
#   '찍다',
#   '종종',
#   '시키다',
#   '먹다',
#   '같다'],
#  ['오늘', '푸다', '지다', '자다', '먹다', '항상', '감사', '드리다'],
#  ['맛', '잇다', '리뷰', '이벤트', '받다', '또', '주문'],
#  ['맛있다'],
#  ['족발', '을', '평소', '엄청', '좋아하다', '않다', '자다', '먹다'],
#  ['쫄깃',
#   '족발',
#   '막국수',
#   '랑',
#   '같이',
#   '먹음',
#   '더',
#   '맛있다',
#   '뼈',
#   '붙다',
#   '고기',
#   '맛있다',
#   '리뷰',
#   '늦다'],
#  ['육질',
#   '부드럽다',
#   '꼬들꼬들',
#   '맛있다',
#   '냄새',
#   '전혀',
#   '없이',
#   '고소하다',
#   '서비스',
#   '로',
#   '주시',
#   '막국수',
#   '면',
#   '쫄깃',
#   '하고',
#   '양념',
#   '맛있다',
#   '매콤',
#   '좋다',
#   '배달',
#   '빨르다',
#   '따뜻하다',
#   '먹다'],
#  ['먹다', '멀리', '배달', '되다'],
#  ['자다', '먹다'],
#  ['막국수',
#   '맛있다',
#   '보쌈',
#   '족발',
#   '이랑',
#   '김치',
#   '진짜',
#   '맛있다',
#   '족발',
#   '시키다',
#   '보쌈',
#   '못',
#   '오다',
#   '전화',
#   '드리다',
#   '하나',
#   '다시',
#   '보내다',
#   '배달',
#   '비도',
#   '안',
#   '받다',
#   '앞',
#   '단골',
#   '등록',
#   '이다',
#   '엄지',
#   '척'],
#  ['좋다', '좋다'],
#  ['족발', '맛있다', '막국수', '맛있다', '다음', '또', '시키다', '같다'],
#  ['맛있다', '양도', '적절하다', '먹다'],
#  ['배달',
#   '바쁘다',
#   '시간',
#   '일텐데',
#   '넘다',
#   '빨리',
#   '오다',
#   '무엇',
#   '보다',
#   '맛',
#   '제',
#   '원하다',
#   '그렇다',
#   '맛',
#   '이다',
#   '너무',
#   '자다',
#   '먹다',
#   '다음',
#   '에도',
#   '배달',
#   '먹다',
#   '보다',
#   '코로나',
#   '로',
#   '힘들다',
#   '화이팅'],
#  ['배달', '엄청', '빨리', '오다', '서비스', '좋다', '맛', '있다'],
#  ['족발',
#   '에서',
#   '냄새',
#   '안나',
#   '서',
#   '넘다',
#   '좋다',
#   '기다',
#   '징',
#   '보내다',
#   '넘다',
#   '먹다',
#   '배달',
#   '엄청',
#   '빠르다',
#   '수고'],
#  ['맛있다', '먹다', '막국수', '좋다'],
#  ['굿굿굿굿굿'],
#  ['맛있다', '먹다'],
#  ['족발', '제', '여기', '서', '만', '시', '켜', '요', '진짜', '맛있다', '양도', '많다'],
#  ['맛있다', '빠르다', '푸다', '짐', '하고'],
#  ['보쌈',
#   '넘다',
#   '부드럽다',
#   '맛있다',
#   '무',
#   '김치',
#   '좋아하다',
#   '많이',
#   '들다',
#   '자다',
#   '먹다',
#   '배달',
#   '해주다',
#   '분도',
#   '문',
#   '앞',
#   '두다',
#   '문자',
#   '까지',
#   '주다',
#   '좋다'],
#  ['요청',
#   '사항',
#   '하나',
#   '하나',
#   '꼼꼼하다',
#   '보고',
#   '확인',
#   '해주다',
#   '감사하다',
#   '오늘',
#   '맛있다',
#   '먹다',
#   '마늘',
#   '소스',
#   '신의',
#   '슈'],
#  ['쫄깃쫄', '깃', '족발', '두', '명', '서', '먹기', '양', '충분하다', '맛있다', '자다', '먹다'],
#  ['보쌈',
#   '맛있다',
#   '연골',
#   '싫어하다',
#   '없다',
#   '부위',
#   '로',
#   '부탁',
#   '드리다',
#   '요청',
#   '사항',
#   '을',
#   '아예',
#   '안',
#   '보다',
#   '듯',
#   '콜라',
#   '안',
#   '주다',
#   '되다',
#   '그냥',
#   '오다'],
#  ['마스크', '같이', '보내다', '감사하다', '맛있다', '자다', '먹다'],
#  ['막국수', '졸맛', '굳이', '에여'],
#  ['맛있다', '배달', '쏘다', '쏘다', '음식', '깔끔하다', '좋다', '먹다', '번창'],
#  ['맛', '잇다', '어', '요'],
#  ['맛', '양', '배달', '삼위일체', '그', '자체', '존맛'],
#  ['맛있다', '먹다', '고추가', '진짜', '엄청', '맵다', '역대', '급'],
#  ['몇',
#   '일전',
#   '먹다',
#   '손님',
#   '대',
#   '접다',
#   '또',
#   '주문',
#   '다',
#   '들다',
#   '맛있다',
#   '차다',
#   '뿌듯하다',
#   '맛있다',
#   '고',
#   '퀄',
#   '음식',
#   '감사',
#   '드리다'],
#  ['족발',
#   '진짜',
#   '맛있다',
#   '일주일',
#   '몇번',
#   '씩',
#   '시키다',
#   '먹다',
#   '같다',
#   '항상',
#   '자다',
#   '먹다',
#   '감사하다'],
#  ['퍽퍽', '하고', '차갑다', '맛', '없다', '냄새', '나', '요', '유독', '제', '시키다', '이렇다', '좋다'],
#  ['자다', '받다', '자다', '먹다'],
#  ['오다',
#   '족발',
#   '맛있다',
#   '먹다',
#   '김치',
#   '터지다',
#   '양념',
#   '새다',
#   '나오다',
#   '일회용',
#   '마스크',
#   '쪽지',
#   '까지',
#   '넣다',
#   '잘쓰다',
#   '고맙다'],
#  ['족발',
#   '이집',
#   '에서만',
#   '먹다',
#   '늘',
#   '맛있다',
#   '막국수',
#   '사이즈',
#   '업',
#   '감사',
#   '드리다',
#   '풍족하다',
#   '먹다',
#   '또',
#   '주문'],
#  ['생각', '맛', '별로', '지만', '배달', '빨리', '오다'],
#  ['양', '푸다', '지다', '자다', '먹다'],
#  ['맛있다', '자다', '먹다'],
#  ['맛있다', '자다', '먹다'],
#  ['족발', '맛있다', '같이', '온', '막국수', '정말', '맛있다'],
#  ['너무', '맛있다', '자주', '시키다', '먹다', '되다'],
#  ['진짜',
#   '고민',
#   '필요없다',
#   '족발',
#   '지다',
#   '자주',
#   '시키다',
#   '먹다',
#   '불',
#   '족발',
#   '처음',
#   '인데',
#   '너무',
#   '맛있다',
#   '행복하다'],
#  ['정말',
#   '정말',
#   '맛',
#   '나다',
#   '먹다',
#   '족발',
#   '을',
#   '좋아하다',
#   '여기저기',
#   '시키다',
#   '보다',
#   '여기',
#   '제일',
#   '맛',
#   '나',
#   '요',
#   '양도',
#   '푸다',
#   '지다',
#   '다음',
#   '또',
#   '시키다'],
#  ['맛있다', '번창'],
#  ['너무', '느끼하다'],
#  ['맛있다', '또', '시키다', '먹다'],
#  ['족발', '정말', '맛있다', '항상', '자다', '먹다', '다음', '또', '주문'],
#  ['배달', '빠르다', '맛있다', '감사하다'],
#  ['너무', '맛있다', '배달', '빠르다'],
#  ['양', '맛', '배달', '다', '좋다'],
#  ['살', '보다', '껍데기', '부분', '더', '많다', '거', '같다', '맛', '있다', '양은', '그냥'],
#  ['막국수', '그냥', '그렇다', '김치', '랑', '족발', '맛있다', '족발', '제대로', '컷팅', '안되다'],
#  ['그냥',
#   '무난',
#   '어디',
#   '서도',
#   '맛보다',
#   '수',
#   '있다',
#   '족발',
#   '맛',
#   '코로나',
#   '로',
#   '배달',
#   '진짜',
#   '오래',
#   '걸리다'],
#  ['맛', '잇다', '앞', '자주', '보다'],
#  ['맛있다'],
#  ['먹다', '사업', '번창'],
#  ['아차',
#   '차',
#   '정신없이',
#   '먹다',
#   '사진',
#   '찍다',
#   '깜빡',
#   '이동',
#   '네',
#   '맛나',
#   '족발',
#   '집',
#   '없다',
#   '이제',
#   '부터',
#   '족발',
#   '이집',
#   '이다',
#   '자다',
#   '먹다'],
#  ['일주일', '한번', '씩', '시키다', '먹다', '이번', '엔', '깜짝', '놀래다', '김치', '에서나', '오다'],
#  ['여러',
#   '번',
#   '배달',
#   '먹다',
#   '멀다',
#   '맛',
#   '정말',
#   '좋다',
#   '배달',
#   '여기',
#   '만',
#   '먹다',
#   '김치',
#   '맛',
#   '정말',
#   '좋다',
#   '여하간',
#   '오늘',
#   '자다',
#   '먹다'],
#  ['막국수', '가안', '익다', '족발', '약', '냄새', '나', '늘다', '제', '입맛', '아니다'],
#  ['배달', '엄청', '빨르다', '1시간', '이래서', '씻다', '15분', '만에왔네요', '맛', '잇다'],
#  ['늦다',
#   '점심',
#   '배고프다',
#   '엄청나다',
#   '먹다',
#   '신랑',
#   '이랑',
#   '둘',
#   '먹다',
#   '쫄깃',
#   '하고',
#   '맛있다',
#   '다음',
#   '또',
#   '시키다',
#   '먹다'],
#  ['맛있다', '먹다'],
#  ['평점', '높다', '이유', '있다', '야들야들'],
#  [],
#  ['배',
#   '터지다',
#   '먹다',
#   '막국수',
#   '맛있다',
#   '보쌈',
#   '처음',
#   '시키다',
#   '먹다',
#   '배',
#   '부르다',
#   '자꾸',
#   '손',
#   '가다',
#   '자다',
#   '억',
#   '었습',
#   '니',
#   '다'],
#  ['덜맵',
#   '게',
#   '해주다',
#   '감사하다',
#   '근데',
#   '양념',
#   '족발',
#   '안',
#   '까지',
#   '깊이',
#   '안',
#   '배다',
#   '같다',
#   '아쉽다',
#   '쟁반',
#   '막국수',
#   '소스',
#   '겨자',
#   '들어가다',
#   '맛있다',
#   '자다',
#   '먹다',
#   '배달',
#   '거의',
#   '50분',
#   '넘어서',
#   '오다',
#   '해',
#   '요',
#   '오래',
#   '걸리다',
#   '족발',
#   '거의',
#   '식다',
#   '오다',
#   '아쉽다'],
#  ['확실하다', '맛있다', '족발', '너무', '식다', '다닥다닥', '붙다', '오다'],
#  ['보쌈', '너무', '늦다', '배달', '되어다', '굳다'],
#  ['항상', '자다', '먹다', '있다'],
#  ['리뷰',
#   '보고',
#   '시키다',
#   '정말',
#   '너무',
#   '맛',
#   '잇다',
#   '자다',
#   '먹다',
#   '습',
#   '니당다',
#   '배달',
#   '엄청',
#   '빨',
#   '라서',
#   '놀라다',
#   '요즘',
#   '같다',
#   '시국',
#   '힘내다'],
#  ['배달',
#   '빠르다',
#   '맛',
#   '아주',
#   '좋다',
#   '양도',
#   '많다',
#   '최근',
#   '좋다',
#   '리뷰',
#   '많다',
#   '이유',
#   '알',
#   '수',
#   '있다'],
#  ['기존',
#   '시키다',
#   '족발',
#   '집',
#   '문',
#   '을',
#   '닫다',
#   '리뷰',
#   '열심히',
#   '검색',
#   '처음',
#   '시키다',
#   '일단',
#   '족발',
#   '잡',
#   '냄새',
#   '안나',
#   '고',
#   '쫄깃',
#   '하고',
#   '맛있다',
#   '막국수',
#   '매다',
#   '걱정',
#   '안',
#   '매다',
#   '맛있다',
#   '콜라',
#   '까지',
#   '세트',
#   '로',
#   '오니',
#   '추가',
#   '메뉴',
#   '시키다',
#   '필요없다',
#   '가성',
#   '비',
#   '좋다',
#   '담',
#   '또',
#   '시키다',
#   '먹다'],
#  ['막국수',
#   '맛',
#   '나다',
#   '족발',
#   '맛있다',
#   '배달',
#   '오다',
#   '때',
#   '족발',
#   '랩',
#   '뜯다',
#   '몇개',
#   '봉지',
#   '애',
#   '들다',
#   '찝찝하다',
#   '나머진',
#   '맛있다',
#   '먹다',
#   '담',
#   '또',
#   '시키다',
#   '규',
#   '요',
#   '쫀득하',
#   '네',
#   '맛있다',
#   '콜라',
#   '오다',
#   '너무',
#   '좋다',
#   '배달',
#   '예상',
#   '시간',
#   '딱',
#   '맞추다',
#   '오다',
#   '족발',
#   '양은',
#   '둘',
#   '먹기',
#   '딱',
#   '좋다',
#   '양인',
#   '듯',
#   '허다',
#   '그렇게',
#   '많다',
#   '않다',
#   '적지',
#   '않다'],
#  ['불',
#   '족발',
#   '매다',
#   '걱정',
#   '맵다',
#   '못',
#   '먹다',
#   '저',
#   '괜찮다',
#   '그냥',
#   '족발',
#   '점',
#   '점',
#   '탱탱하다',
#   '쫄깃쫄깃',
#   '한데',
#   '불',
#   '족발',
#   '거의',
#   '부서지다',
#   '살코기',
#   '랑',
#   '껍떼기',
#   '부분',
#   '분리',
#   '돼다',
#   '오다',
#   '비',
#   '오다',
#   '걱정',
#   '배달',
#   '분',
#   '시간',
#   '맞추다',
#   '친절하다',
#   '자다',
#   '배달',
#   '해',
#   '주다'],
#  ['오우', '오우', '둘이서', '아주', '들다', '들다', '먹다', '버리다'],
#  ['맛있다', '먹다', '제', '입', '짜다', '김치', '맛있다'],
#  ['2',
#   '명',
#   '에서',
#   '먹기',
#   '괜찮다',
#   '냄새',
#   '안나',
#   '고',
#   '배달',
#   '빠르다',
#   '감사히',
#   '자다',
#   '먹다'],
#  ['오랜', '만', '맛', '난', '족발', '먹다'],
#  ['맛있다', '자다', '먹다'],
#  ['양도', '괜찬', '고', '맛있다', '먹다'],
#  ['너무',
#   '빨리',
#   '먹다',
#   '사진',
#   '을',
#   '못',
#   '찍다',
#   '가족',
#   '이랑',
#   '같이',
#   '맛있다',
#   '먹다',
#   '배달',
#   '해주다',
#   '분도',
#   '너무',
#   '친절하다'],
#  ['양', '작다', '해', '요'],
#  ['신',
#   '우리',
#   '식구',
#   '대식',
#   '이다',
#   '꽃',
#   '보다',
#   '족발',
#   '크다',
#   '시키다',
#   '다',
#   '들다',
#   '풍족하다',
#   '먹다',
#   '완전',
#   '맛있다',
#   '구성',
#   '알차다'],
#  ['사진', '을', '못', '찍다', '맛있다', '자다', '먹다'],
#  ['지난번',
#   '먹다',
#   '때',
#   '보다',
#   '맛있엇눈데',
#   '양',
#   '적다',
#   '담',
#   '엔',
#   '중',
#   '시키다',
#   '먹다',
#   '습',
#   '니',
#   '단'],
#  ['족발',
#   '진짜',
#   '맛있다',
#   '항상',
#   '변하다',
#   '없다',
#   '맛',
#   '감사하다',
#   '리뷰',
#   '안',
#   '남기다',
#   '너무',
#   '맛있다',
#   '안달',
#   '수가',
#   '없다',
#   '또',
#   '주문'],
#  ['배달',
#   '안',
#   '오다',
#   '전화',
#   '여러',
#   '번',
#   '전화',
#   '안',
#   '받다',
#   '가타',
#   '부타',
#   '말',
#   '없이',
#   '그냥',
#   '집',
#   '앞',
#   '두다',
#   '가다',
#   '제',
#   '안나',
#   '가보다',
#   '어쩌실려',
#   '고',
#   '그렇다',
#   '이해',
#   '안되다',
#   '그나마',
#   '보쌈',
#   '맛',
#   '괜찮다',
#   '참다',
#   '암튼',
#   '앞',
#   '다시다',
#   '안',
#   '시키다',
#   '듯',
#   '요'],
#  ['맛있다', '자다', '먹다'],
#  ['맛',
#   '이랑',
#   '양도',
#   '충분하다',
#   '세심',
#   '마스크',
#   '까지',
#   '챙기다',
#   '감동',
#   '음식',
#   '맛',
#   '나다',
#   '좋다'],
#  ['배달', '시간', '걸리다', '빼다', '만족스럽다', '맛', '나', '여'],
#  ['처음', '시키다', '보다', '맛있다', '김치', '랑', '막국수', '맛있다', '다음', '에도', '또', '주문'],
#  ['맛있다', '먹다', '다음', '또', '시키다', '먹다'],
#  ['오랜', '만', '불', '족발', '먹다', '시키다', '맛있다'],
#  ['상당하다',
#   '아주',
#   '만족하다',
#   '먹다',
#   '이렇다',
#   '소소하다',
#   '신경',
#   '써주다',
#   '부분',
#   '너무',
#   '좋다',
#   '감사하다'],
#  ['족발', '막국수', '주다', '너무', '맛있다', '배달', '너무', '늦다'],
#  ['비',
#   '오다',
#   '그런',
#   '건',
#   '지',
#   '80분',
#   '걸린다는',
#   '배달',
#   '2시간',
#   '넘다',
#   '주문',
#   '누락',
#   '된거',
#   '같다',
#   '아니다',
#   '주문',
#   '밀리다',
#   '서다',
#   '그렇다',
#   '미리',
#   '연락',
#   '주다',
#   '좋다',
#   '같다',
#   '반',
#   '반',
#   '족발',
#   '시키다',
#   '족발',
#   '괜찮다',
#   '불족',
#   '쏘다',
#   '쏘다'],
#  ['족발',
#   '만',
#   '시키다',
#   '먹다',
#   '보쌈',
#   '땡기다',
#   '주문',
#   '역시',
#   '맛',
#   '나다',
#   '족발',
#   '보쌈',
#   '여기',
#   '가젤',
#   '루맛',
#   '나',
#   '늘다',
#   '같다'],
#  ['배달', '부가', '지다', '주소', '헷갈리다', '적반하장', '지다', '짜증', '내다', '어이', '없다', '농'],
#  ['족발',
#   '쫀득',
#   '하고',
#   '양도',
#   '많다',
#   '먹기',
#   '좋다',
#   '막국수',
#   '까지',
#   '같이',
#   '오다',
#   '든든하다',
#   '먹다'],
#  ['맛있다', '어유', '마늘', '소스', '맛있다', '유'],
#  ['배달', '늦다', '전화하다', '끊다', '버리다', '별로', '이다'],
#  ['둘이서',
#   '너무',
#   '맛있다',
#   '배부르다',
#   '먹다',
#   '불족',
#   '리뷰',
#   '에서',
#   '안',
#   '매다',
#   '맵다',
#   '못',
#   '들다',
#   '분',
#   '약간',
#   '매콤',
#   '수',
#   '있다',
#   '그리고',
#   '일반',
#   '족발',
#   '살짝',
#   '돼지',
#   '냄새',
#   '나다',
#   '막국수',
#   '사이즈',
#   '업',
#   '너무',
#   '좋다',
#   '이벤트',
#   '같다',
#   '배달',
#   '시간',
#   '넘다',
#   '걸리다',
#   '만족하다',
#   '먹다'],
#  ['막국수', '사이', '즈', '업', '해주다', '맞다', '맛있다'],
#  ['먹다', '만해', '요', '냄새', '안나', '고', '쏘다', '호', '야식', '굳다'],
#  ['주문',
#   '많이',
#   '밀리다',
#   '주문',
#   '하고',
#   '1시간',
#   '반',
#   '만에',
#   '받다',
#   '그래도',
#   '맛있다',
#   '먹다',
#   '족발',
#   '양',
#   '괜찮다',
#   '맛있다',
#   '중',
#   '사이즈',
#   '둘이서',
#   '먹기',
#   '좋다',
#   '김치',
#   '랑',
#   '무',
#   '절임',
#   '맛있다',
#   '그렇지만',
#   '막국수',
#   '조금',
#   '달다',
#   '아쉽다'],
#  ['배달',
#   '원',
#   '분',
#   '마스크',
#   '자다',
#   '착용',
#   '해주다',
#   '좋다',
#   '배달',
#   '빨리',
#   '오다',
#   '더',
#   '좋다',
#   '가장',
#   '좋다',
#   '건',
#   '족발',
#   '엄청',
#   '맛있다',
#   '다음',
#   '또',
#   '시키다'],
#  ['배달', '늦다', '정말', '기다리다', '보람', '있다', '감사히', '먹다'],
#  [],
#  ['저번',
#   '주',
#   '먹다',
#   '자꾸',
#   '생각나다',
#   '또',
#   '시키다',
#   '오늘',
#   '따르다',
#   '막국수',
#   '예술',
#   '이네',
#   '요',
#   '살찌다'],
#  ['저번',
#   '너무',
#   '맛있다',
#   '재',
#   '주문',
#   '너무',
#   '양도',
#   '많다',
#   '배달',
#   '빠르다',
#   '맛있다',
#   '먹다',
#   '양',
#   '어마어마하다',
#   '사실',
#   '처음',
#   '엔',
#   '양',
#   '많다',
#   '보다',
#   '맛',
#   '별로',
#   '겠다',
#   '진짜',
#   '믿다',
#   '먹다',
#   '만해',
#   '요'],
#  ['포장',
#   '꼼꼼하다',
#   '양도',
#   '적다',
#   '보이다',
#   '막국수',
#   '까지',
#   '여자',
#   '세명',
#   '먹기',
#   '적당하다',
#   '근데',
#   '전체',
#   '적',
#   '간이',
#   '세다',
#   '아쉽다',
#   '그래도',
#   '배달',
#   '해주다',
#   '분도',
#   '친절하다',
#   '마스크',
#   '막국수',
#   '사이즈',
#   '업도',
#   '감사하다'],
#  ['너무', '맛있다', '신속하다', '좋다', '족발', '무조건', '여기', '서', '시키다', '먹다'],
#  ['맛', '나', '요', '요청', '사항', '보다', '아쉽다'],
#  ['친구', '랑', '호캉스', '시키다', '먹다', '정말', '맛있다'],
#  ['맛있다', '자다', '먹다'],
#  ['맛있다',
#   '자다',
#   '먹다',
#   '족발',
#   '을',
#   '너무',
#   '좋아하다',
#   '까다롭다',
#   '입맛',
#   '아이',
#   '너무',
#   '맛있다',
#   '자다',
#   '먹다',
#   '잡다',
#   '안나',
#   '고',
#   '부드럽다',
#   '깊다',
#   '내공',
#   '맛',
#   '느껴지다',
#   '동네',
#   '있다',
#   '좋다',
#   '을지로',
#   '방문',
#   '꼭',
#   '다시',
#   '주문'],
#  ['항상', '먹다'],
#  ['생각', '보다', '양', '많다'],
#  ['성인',
#   '4',
#   '명',
#   '이서',
#   '쫄깃쫄깃',
#   '맛있다',
#   '먹다',
#   '고기',
#   '너무',
#   '맛있다',
#   '마늘',
#   '소스',
#   '너무',
#   '좋다',
#   '김치',
#   '등등',
#   '너무',
#   '자다',
#   '먹다',
#   '담',
#   '에도',
#   '또',
#   '주문'],
#  ['꺅', '맛있다'],
#  ['맛있다',
#   '먹다',
#   '고기',
#   '양',
#   '조금',
#   '아쉽다',
#   '막국수',
#   '겨자',
#   '냄새',
#   '나다',
#   '그렇게',
#   '막',
#   '신경',
#   '쓰이다',
#   '정도',
#   '아니다',
#   '무난',
#   '먹다',
#   '같다',
#   '고기',
#   '양',
#   '생각',
#   '보다',
#   '적다',
#   '김치양',
#   '넉넉하다',
#   '대',
#   '채',
#   '로',
#   '자다',
#   '먹다',
#   '같다',
#   '고추',
#   '약간',
#   '쫌',
#   '매다'],
#  ['맵다',
#   '어느',
#   '집',
#   '이든',
#   '항상',
#   '달',
#   '게',
#   '오다',
#   '단맛',
#   '싫다',
#   '남친',
#   '먹기',
#   '싫다',
#   '요청',
#   '사항',
#   '단맛',
#   '빼',
#   '달라',
#   '고',
#   '빼다',
#   '맛있다',
#   '먹다',
#   '기존',
#   '레시피',
#   '있다',
#   '귀찮다',
#   '입맛',
#   '맞다',
#   '해주다',
#   '감사하다',
#   '먹다'],
#  ['배달',
#   '빠르다',
#   '맛',
#   '좋다',
#   '구성',
#   '좋다',
#   '모두',
#   '만족하다',
#   '무엇',
#   '보다',
#   '고기',
#   '예술',
#   '이네',
#   '요',
#   '자주',
#   '시키다',
#   '먹다'],
#  ['감동'],
#  ['리뷰', '쓸다', '굿', '마스크', '잘쓰다'],
#  ['배달',
#   '시간',
#   '적당하다',
#   '양은',
#   '너무',
#   '너무',
#   '만족하다',
#   '맛',
#   '좋다',
#   '냉채',
#   '족발',
#   '야채',
#   '신선하다',
#   '소스',
#   '좋다',
#   '앞',
#   '여기',
#   '서',
#   '만',
#   '시키다'],
#  ['늘',
#   '맛있다',
#   '먹다',
#   '행',
#   '당',
#   '에서',
#   '족발',
#   '제일',
#   '맛있다',
#   '집',
#   '인데',
#   '족발',
#   '을',
#   '먹다',
#   '없다',
#   '사진',
#   '처럼',
#   '전부',
#   '다',
#   '비계',
#   '안',
#   '에도',
#   '비계',
#   '족발',
#   '좋아하다',
#   '여러',
#   '군데',
#   '먹다',
#   '보다',
#   '십',
#   '몇',
#   '년',
#   '동안',
#   '이렇다',
#   '퀄리티',
#   '처음',
#   '이다',
#   '처음',
#   '에는',
#   '웃다',
#   '살이',
#   '많다',
#   '돼지',
#   '인가',
#   '보다',
#   '보쌈',
#   '이랑',
#   '막국수',
#   '맛있다',
#   '먹다'],
#  ['양도', '많다', '맛있다', '먹다'],
#  ['요기',
#   '요',
#   '배달',
#   '이렇다',
#   '첨으로',
#   '리뷰',
#   '작성',
#   '해보다',
#   '맛있다',
#   '배달',
#   '빠르다',
#   '양도',
#   '풍',
#   '성하다',
#   '몇',
#   '군데',
#   '실패하다',
#   '이번',
#   '맛있다',
#   '이름',
#   '기억',
#   '하자',
#   '며',
#   '약속',
#   '리뷰',
#   '작',
#   '성해',
#   '서',
#   '상호',
#   '이름',
#   '더',
#   '자다',
#   '기억',
#   '되다',
#   '저렴하다',
#   '맛',
#   '나다',
#   '많이',
#   '파다'],
#  ['맛', '좋다', '양도', '많다', '배달', '빠르다', '너무', '좋다'],
#  ['언제', '먹다', '맛', '잇다', '배달', '정확하다', '굿굿굿'],
#  ['반', '반', '너무', '너무', '맛있다', '또', '시키다', '먹다'],
#  ['두번째', '주문', '너무', '맛있다'],
#  ['맛있다', '자다', '먹다'],
#  ['맛있다', '먹다'],
#  ['회사', '선배', '추천', '먹다', '너무', '밋', '있다'],
#  ['맛있다', '또', '주문', '먹다', '읍니', '다'],
#  ['맛있다',
#   '특대',
#   '시키다',
#   '비',
#   '적다',
#   '밑',
#   '뼈',
#   '많다',
#   '그리고',
#   '위',
#   '고기',
#   '짜다',
#   '말다',
#   '붙다',
#   '조금',
#   '바쁘다',
#   '보다',
#   '불',
#   '족발',
#   '너무',
#   '맵',
#   '지',
#   '않다',
#   '괜찮다',
#   '막국수',
#   '괜찮다',
#   '뼈',
#   '보다',
#   '고기',
#   '양',
#   '을',
#   '늘리다',
#   '야하다',
#   '같다'],
#  ['진짜', '맛있다', '먹다', '있다', '족발', '맛있다', '막국수', '맛있다', '추천', '추천'],
#  ['고기', '맛있다', '쌈', '채소', '신선하다', '않다'],
#  ['비다',
#   '고생',
#   '많다',
#   '배달',
#   '조심하다',
#   '오늘',
#   '족발',
#   '얇다',
#   '썰다',
#   '달라',
#   '고',
#   '부탁드리다',
#   '너무',
#   '두껍다',
#   '오다',
#   '아쉽다',
#   '칼',
#   '로',
#   '다시',
#   '썰다',
#   '먹다',
#   '있다',
#   '여전하다',
#   '맛있다',
#   '수고'],
#  ['모든', '것', '다', '좋다'],
#  ['2',
#   '번째',
#   '주문',
#   '인데',
#   '확실하다',
#   '다른',
#   '집',
#   '보다',
#   '맛있다',
#   '찌다',
#   '오라버니',
#   '극찬',
#   '맛있다',
#   '자다',
#   '먹다'],
#  ['맛있다', '먹다', '양', '조금', '부족', '햇', '어', '용'],
#  ['맛있다',
#   '양',
#   '많다',
#   '사람',
#   '둘이서',
#   '배부르다',
#   '먹다',
#   '정도',
#   '양',
#   '이에요',
#   '리뷰',
#   '이벤트',
#   '로',
#   '막국수',
#   '사이',
#   '즈',
#   '업',
#   '해주다',
#   '맛있다',
#   '자다',
#   '먹다',
#   '습',
#   '니당다',
#   '사진',
#   '오',
#   '자마자',
#   '급하다',
#   '먹다',
#   '찍다',
#   '없다',
#   '보이',
#   '네',
#   '용'],
#  ['항상', '맛있다', '양도', '많다', '깔끔하다'],
#  ['이번',
#   '엔',
#   '살짝',
#   '고기',
#   '양',
#   '적다',
#   '같다',
#   '기분',
#   '탓',
#   '겠다',
#   '항상',
#   '맛있다',
#   '자다',
#   '먹다',
#   '있다'],
#  ['배달',
#   '너무',
#   '빠르다',
#   '이렇다',
#   '시국',
#   '마스크',
#   '센스',
#   '너무',
#   '좋다',
#   '맛',
#   '당연하다',
#   '있다',
#   '덕분',
#   '배부르다',
#   '먹다',
#   '마스크',
#   '까지',
#   '생기다',
#   '잘쓰다',
#   '번창'],
#  ['기', '막히다', '코', '막히다', '맛', '이네', '요'],
#  ['너무', '맛', '잇다', '양도', '푸다', '짐', '하고'],
#  ['냄새', '안나', '고', '너무', '맛있다'],
#  ['맛있다', '배달', '시간', '하고', '양', '모두', '적절하다', '오다'],
#  ['넘다', '맛있다', '먹다', '최고'],
#  ['맛', '나', '요'],
#  ['서비스', '양', '대해', '서다', '만족하다'],
#  ['족발',
#   '보쌈',
#   '미지근하다',
#   '그냥',
#   '맛있다',
#   '맛없다',
#   '않다',
#   '그렇다',
#   '맛',
#   '이다',
#   '그냥',
#   '제',
#   '개인',
#   '적',
#   '인',
#   '의견',
#   '이다',
#   '그래도',
#   '가족',
#   '끼리',
#   '모',
#   '여서',
#   '다',
#   '먹다',
#   '습',
#   '니당다'],
#  ['맛있다', '맛있다'],
#  ['자다', '먹다', '양', '많다', '맛있다'],
#  ['배달',
#   '빠르다',
#   '좋다',
#   '맛',
#   '괜찮다',
#   '전',
#   '개인',
#   '적',
#   '야들야들하다',
#   '좋아하다',
#   '오늘',
#   '살짝',
#   '들다',
#   '야들야들하다',
#   '그래도',
#   '만족하다'],
#  ['문어',
#   '삼',
#   '합',
#   '맛있다',
#   '둘',
#   '먹기',
#   '딱',
#   '양도',
#   '적당하다',
#   '어떤',
#   '분',
#   '적다',
#   '요',
#   '저',
#   '희다',
#   '딱',
#   '좋다'],
#  ['맛', '있다', '근데', '야채', '너무', '부실하다'],
#  ['오늘',
#   '말복',
#   '이라',
#   '뭐',
#   '먹다',
#   '고민',
#   '족발',
#   '안',
#   '먹다',
#   '한참',
#   '되다',
#   '시키다',
#   '처음',
#   '주문',
#   '곳',
#   '이라',
#   '크다',
#   '기대다',
#   '안',
#   '하고',
#   '주문',
#   '배달',
#   '주신',
#   '기사',
#   '님',
#   '부터',
#   '정말로',
#   '너무',
#   '친절',
#   '느낌',
#   '좋다',
#   '느낌',
#   '적중',
#   '너무',
#   '너무',
#   '맛있다',
#   '자다',
#   '먹다',
#   '제',
#   '뼈',
#   '붙다',
#   '고기',
#   '까지',
#   '먹다',
#   '요',
#   '죄송하다',
#   '사진',
#   '을',
#   '못',
#   '찍다',
#   '담',
#   '시키다',
#   '땐',
#   '꼭',
#   '사진',
#   '리뷰',
#   '사장',
#   '님',
#   '맛있다',
#   '자다',
#   '먹다'],
#  ['너무', '맛있다', '양도', '좋다', '다음', '에도', '시키다'],
#  ['항상', '맛있다', '너무', '먹다'],
#  ['평소',
#   '보쌈',
#   '무난',
#   '생각',
#   '오늘',
#   '따르다',
#   '유난히',
#   '보쌈',
#   '맛있다',
#   '앞',
#   '으로도',
#   '계속',
#   '맛',
#   '이다',
#   '좋다',
#   '족발',
#   '평소',
#   '처럼',
#   '맛있다'],
#  ['맛있다', '먹다'],
#  ['리얼', '뤼리얼뤼', '베리', '굿', '마스크', '선물', '감사하다'],
#  ['너무', '맛있다', '먹다', '스', '비다'],
#  ['진짜',
#   '맛있다',
#   '가격',
#   '합리',
#   '적',
#   '이고',
#   '막국수',
#   '인상',
#   '적',
#   '이고',
#   '족발',
#   '쫀득해',
#   '요'],
#  ['맛있다', '자다', '먹다', '습', '니당다'],
#  ['여기', '진짜', '존맛', '탱', '또', '시키다', '먹다', '중', '이다'],
#  ['네이스', '네이스', '네이스', '메이스'],
#  ['혼자', '먹기', '조금', '많다'],
#  ['빨리', '오다', '맛', '있다'],
#  ['아주', '맛있다', '먹다'],
#  ['맛있다', '자다', '먹다'],
#  ['족발', '달', '지', '않다', '맛있다', '불', '족발', '적당하다', '매콤', '맛있다'],
#  ['맛있다', '먹다', '습', '니당다', '양은', '적다'],
#  ['처음',
#   '시키다',
#   '보다',
#   '배달',
#   '예',
#   '정시',
#   '간',
#   '보다',
#   '빨리',
#   '배달',
#   '해주다',
#   '양도',
#   '생각',
#   '보다',
#   '많다',
#   '특히',
#   '불',
#   '족발',
#   '너무',
#   '맛있다',
#   '다르다',
#   '다',
#   '먹다',
#   '보다',
#   '여기',
#   '족발',
#   '너무',
#   '맛있다',
#   '먹다',
#   '앞',
#   '자주',
#   '시키다',
#   '먹다',
#   '같다',
#   '번창'],
#  ['고기',
#   '진짜',
#   '촉촉쫄깃',
#   '탱탱',
#   '먹다',
#   '때',
#   '마다',
#   '감동',
#   '이다',
#   '또',
#   '시키다',
#   '서비스',
#   '막국수',
#   '너무',
#   '잘머었어',
#   '요'],
#  ['배달',
#   '오',
#   '자마자',
#   '펼치다',
#   '뭐',
#   '포장',
#   '지안',
#   '에서',
#   '날아다니다',
#   '족발',
#   '그냥',
#   '저',
#   '냥',
#   '먹다',
#   '기분',
#   '너무',
#   '좋다',
#   '않다',
#   '다',
#   '남기다',
#   '다른',
#   '피해자',
#   '더',
#   '나오다',
#   '않다',
#   '확인',
#   '포장',
#   '부탁드리다'],
#  ['그냥',
#   '포인트',
#   '상관없다',
#   '리뷰',
#   '남기다',
#   '배고프다',
#   '사진',
#   '못',
#   '찍다',
#   '주말',
#   '처음',
#   '주문',
#   '먹다',
#   '정말',
#   '맛있다',
#   '오늘',
#   '또',
#   '먹다',
#   '엄마',
#   '김치',
#   '맛있다',
#   '오늘',
#   '김치',
#   '크다',
#   '걸',
#   '시키다',
#   '김치',
#   '많이',
#   '줄다',
#   '다른',
#   '가게',
#   '보통',
#   '주문',
#   '몆',
#   '번하다',
#   '맛',
#   '변하다',
#   '계속',
#   '맛있다',
#   '족발',
#   '부탁드리다'],
#  ['불',
#   '족발',
#   '불향',
#   '나다',
#   '가족',
#   '모두',
#   '먹다',
#   '맛있다',
#   '먹다',
#   '아빠',
#   '불족',
#   '으로만',
#   '시키다',
#   '우리',
#   '다',
#   '먹다',
#   '게다',
#   '고',
#   '정도',
#   '이다',
#   '일',
#   '반',
#   '족발',
#   '그저',
#   '그렇다',
#   '그리고',
#   '막국수',
#   '톡',
#   '쏘다',
#   '맛',
#   '강하다',
#   '그렇다',
#   '그런',
#   '맛',
#   '좋아하다',
#   '맛있다',
#   '먹다',
#   '해',
#   '요',
#   '그래도',
#   '비다',
#   '배달',
#   '빠르다',
#   '따다',
#   '배달',
#   '서다',
#   '먹다'],
#  ['왠만하다',
#   '귀찮다',
#   '리뷰',
#   '안',
#   '남기다',
#   '진짜',
#   '맛없다',
#   '기본',
#   '적',
#   '인',
#   '젓가락',
#   '없다',
#   '맛',
#   '무슨',
#   '태국',
#   '에서',
#   '먹다',
#   '맛',
#   '나다',
#   '남',
#   '맛있다',
#   '내',
#   '입맛',
#   '다른',
#   '건',
#   '지',
#   '다시다',
#   '안',
#   '시키다',
#   '저'],
#  ['좋다', '맛있다', '오래', '먹다'],
#  ['맛', '양', '배달', '모두', '굿굿', '다음', '또', '시키다', '먹다', '감사하다'],
#  ['배달', '빠르다', '먹다'],
#  ['이벤트',
#   '참여',
#   '한다해',
#   '놓다',
#   '닉네임',
#   '안',
#   '쓰다',
#   '바보',
#   '짓',
#   '을',
#   '해',
#   '버리다',
#   '어찌',
#   '돼다',
#   '맛있다',
#   '양도',
#   '넉넉하다',
#   '좋다'],
#  ['막국수',
#   '넓다',
#   '접시',
#   '보내다',
#   '먹기',
#   '편하다',
#   '좋다',
#   '족발',
#   '맛있다',
#   '양도',
#   '적당하다',
#   '맛있다',
#   '먹다'],
#  ['맛있다', '자주', '찾다', '되다'],
#  ['양', '맛', '배달', '좋다', '맛있다'],
#  ['양도', '푸다', '짐', '하고', '맛있다'],
#  ['족발', '진짜', '맛있다', '맨날', '먹다', '맛', '이네', '요', '야채', '신선하다', '좋다', '감사하다'],
#  ['족발',
#   '보쌈',
#   '세트',
#   '아주',
#   '좋다',
#   '진짜',
#   '여기',
#   '말고는',
#   '이제',
#   '못',
#   '시키다',
#   '먹다',
#   '비다',
#   '고생',
#   '많이',
#   '감사하다'],
#  ['비도',
#   '오다',
#   '음식',
#   '따뜻하다',
#   '자다',
#   '도착',
#   '넘다',
#   '맛',
#   '잇다',
#   '잘먹엇어',
#   '요',
#   '역시',
#   '나',
#   '꽃족',
#   '이에요'],
#  ['별로', '이다'],
#  ['국수', '불지', '않다', '김치', '도달', '지', '않다', '너무', '먹다', '감사하다'],
#  ['맛있다', '깔끔하다', '껍데기', '조금', '짜다', '구성', '아주', '좋다'],
#  ['도루', '왕', '양의지', '너무', '밋있', '고', '양도', '푸다', '지다', '좋다'],
#  ['배달', '예', '정시', '간', '보다', '30분', '늦다', '오다'],
#  ['기본', '충실하다', '맛', '가격', '착하다', '맛있다', '추천'],
#  ['맛있다', '자다', '먹다'],
#  ['양도', '많다', '맛', '좋다', '최고', '예요'],
#  ['배달', '딱', '69분', '걸리다', '맛', '있다'],
#  ['다',
#   '먹다',
#   '버리다',
#   '사진',
#   '없다',
#   '성',
#   '구',
#   '살다',
#   '제일',
#   '맛있다',
#   '먹다',
#   '집',
#   '이다',
#   '이번',
#   '에도',
#   '정말',
#   '맛있다',
#   '먹다'],
#  ['맛',
#   '양',
#   '충분하다',
#   '배고프다',
#   '허겁지겁',
#   '먹다',
#   '찎었네',
#   '요',
#   '다만',
#   '요즘',
#   '비',
#   '많이',
#   '오다',
#   '배달',
#   '시간',
#   '걸리다',
#   '아쉽다'],
#  ['감사하다', '맛', '나다', '먹다'],
#  ['감사하다'],
#  ['너무',
#   '배고프다',
#   '급하다',
#   '먹다',
#   '사진',
#   '못',
#   '찍다',
#   '역시',
#   '나',
#   '양도',
#   '많다',
#   '쟁반',
#   '국수',
#   '사이즈',
#   '어마어마하다',
#   '나누다',
#   '먹다',
#   '남다',
#   '번창'],
#  ['배송', '늦다', '빼다', '족발', '맛있다'],
#  ['맛있다',
#   '먹다',
#   '리뷰',
#   '쓰다',
#   '사이즈',
#   '업',
#   '되다',
#   '막국수',
#   '양',
#   '정말',
#   '대단하다',
#   '맛있다',
#   '먹다',
#   '족발',
#   '특히',
#   '좋다'],
#  ['다른',
#   '족발',
#   '집다',
#   '너무',
#   '달다',
#   '물리다',
#   '집다',
#   '딱',
#   '옛날',
#   '맛',
#   '이에요',
#   '불필요하다',
#   '없이',
#   '먹다',
#   '것',
#   '만',
#   '주다',
#   '것',
#   '맘',
#   '듭니',
#   '다'],
#  ['어떻다',
#   '리뷰',
#   '쓸다',
#   '고민',
#   '이제',
#   '쓰다',
#   '처음',
#   '엔',
#   '중',
#   '시키다',
#   '양',
#   '많다',
#   '생각',
#   '이건',
#   '뼈',
#   '너무',
#   '많다',
#   '아니다',
#   '서비스',
#   '로',
#   '주신',
#   '막국수',
#   '나머지',
#   '다른',
#   '채소',
#   '신선하다',
#   '맛있다'],
#  ['맛있다', '먹다'],
#  ['맛있다', '맛있다'],
#  ['둘', '먹기', '양도', '많다', '맛있다'],
#  ['비다',
#   '총알',
#   '배송',
#   '해주다',
#   '거의',
#   '15분',
#   '만에',
#   '온',
#   '것',
#   '같다',
#   '미끄럽다',
#   '이리',
#   '빠르다',
#   '맛',
#   '난',
#   '음식',
#   '을',
#   '배달',
#   '해주다',
#   '감사하다',
#   '사장',
#   '님',
#   '사업',
#   '번창',
#   '기쁘다',
#   '단골',
#   '이구',
#   '요',
#   '맛있다',
#   '양도',
#   '푸다',
#   '지다',
#   '늘',
#   '시키다',
#   '먹다',
#   '맛',
#   '난',
#   '음식',
#   '감사하다'],
#  ['배달', '빠르다', '소자', '시키다', '맛', '양도', '딱', '알맞다', '좋다'],
#  ['생각',
#   '보다',
#   '맛있다',
#   '막국수',
#   '면은',
#   '분명',
#   '좋다',
#   '면은',
#   '아니다',
#   '소스',
#   '야채',
#   '아',
#   '삭함',
#   '정말',
#   '면',
#   '맛',
#   '을',
#   '생각',
#   '못',
#   '맛있다',
#   '말',
#   '밖에',
#   '알다',
#   '족발',
#   '맛있다',
#   '막국수',
#   '싸',
#   '먹다',
#   '최고',
#   '이다',
#   '주문',
#   '밀리다',
#   '오래',
#   '기다리다',
#   '다음',
#   '에도',
#   '시키다',
#   '양',
#   '소식',
#   '3',
#   '명',
#   '에겐',
#   '많다',
#   '족발',
#   '사이즈',
#   '줄',
#   '이고',
#   '막국수',
#   '곁들이다',
#   '먹다'],
#  ['배달', '너무', '늦다', '맛', '최고', '에요'],
#  ['완전',
#   '푸다',
#   '짐',
#   '하고',
#   '고기',
#   '잘살다',
#   '킹왕짱',
#   '진짜',
#   '알짜',
#   '배기',
#   '또',
#   '먹다',
#   '오다'],
#  ['족발', '맛있다', '막국수', '사이즈', '업', '양', '왕', '많다'],
#  ['배달', '빠르다', '불', '족발', '너무', '맛있다'],
#  ['일단',
#   '맛있다',
#   '소자',
#   '혼자',
#   '안남',
#   '기고',
#   '먹기',
#   '딱',
#   '맞다',
#   '양',
#   '이다',
#   '많다',
#   '적지',
#   '않다',
#   '개인',
#   '적',
#   '배달',
#   '비',
#   '3천원',
#   '받다',
#   '김치',
#   '아쉽다',
#   '해도',
#   '전체',
#   '적',
#   '만족스럽다'],
#  ['양', '많다', '맛있다', '습', '니당다'],
#  ['역시', '꽃', '보다', '족발', '맛', '좋다', '영양가', '좋다', '단골', '인', '이유', '있다'],
#  ['배달',
#   '예상',
#   '시간',
#   '보다',
#   '일찍',
#   '해주다',
#   '빗다',
#   '고맙다',
#   '족발',
#   '남자',
#   '1',
#   '여자',
#   '1',
#   '소식',
#   '먹기',
#   '충분하다',
#   '부드럽다',
#   '식감',
#   '맛있다',
#   '첨',
#   '엔',
#   '달다',
#   '싶다',
#   '상추',
#   '마늘',
#   '고추',
#   '쌈장',
#   '넣다',
#   '단',
#   '짜다',
#   '조화',
#   '이다',
#   '막국수',
#   '많이',
#   '주시',
#   '고',
#   '다만',
#   '보쌈',
#   '김치',
#   '덜',
#   '달',
#   '면',
#   '좋다'],
#  ['맛있다',
#   '먹다',
#   '막국수',
#   '맛있다',
#   '먹다',
#   '급하다',
#   '먹다',
#   '보다',
#   '다',
#   '먹다',
#   '리뷰',
#   '쓰다',
#   '되다'],
#  ['그냥',
#   '족발',
#   '맛있다',
#   '저번',
#   '불',
#   '족발',
#   '먹다',
#   '이번',
#   '엔',
#   '그냥',
#   '족발',
#   '시키다',
#   '보다',
#   '꼬들꼬들하다',
#   '넘다',
#   '맛있다',
#   '먹다',
#   '또',
#   '시키다',
#   '번창'],
#  ['먹다', '먹다'],
#  ['맛', '좋다', '배달', '빨르다'],
#  ['사진',
#   '을',
#   '못',
#   '찍다',
#   '개인',
#   '적',
#   '으로는',
#   '아주',
#   '야들야들하다',
#   '좋아하다',
#   '오늘',
#   '것',
#   '제',
#   '기준',
#   '에는',
#   '야',
#   '깔다',
#   '못',
#   '미치다',
#   '그래도',
#   '맛있다',
#   '배',
#   '고프다',
#   '기다리다',
#   '지루하다',
#   '시간대',
#   '감안',
#   '시',
#   '비교',
#   '적',
#   '빨리',
#   '오다'],
#  ['이번', '에도', '아주', '맛있다', '먹다'],
#  ['양은',
#   '진짜',
#   '많다',
#   '맛있다',
#   '먹다',
#   '보쌈',
#   '살',
#   '보단',
#   '비계',
#   '더',
#   '많다',
#   '느낌',
#   '이라',
#   '아쉽다'],
#  ['둘',
#   '먹다',
#   '시키다',
#   '진짜',
#   '배부르다',
#   '다',
#   '못',
#   '먹다',
#   '맛',
#   '맛',
#   '이고',
#   '양도',
#   '진짜',
#   '많다',
#   '보쌈',
#   '시키다',
#   '먹다',
#   '처음',
#   '인데',
#   '담',
#   '족발',
#   '시키다',
#   '보다'],
#  ['저번',
#   '먹다',
#   '때',
#   '보다',
#   '쟁반',
#   '국수',
#   '훨',
#   '씬',
#   '맛있다',
#   '져서',
#   '진짜',
#   '맛있다',
#   '먹다',
#   '고기',
#   '원래',
#   '맛있다',
#   '덕분',
#   '너무',
#   '맛있다',
#   '푸다',
#   '지다',
#   '자다',
#   '먹다',
#   '배',
#   '많이',
#   '고프다',
#   '사진',
#   '을',
#   '찍',
#   '을',
#   '생각',
#   '못',
#   '하고',
#   '정신없이',
#   '먹다',
#   '담',
#   '주문',
#   '사진',
#   '함께',
#   '리뷰',
#   '올리다'],
#  ['실수',
#   '로',
#   '보쌈',
#   '시키다',
#   '족발',
#   '을',
#   '시키다',
#   '자다',
#   '먹다',
#   '참고',
#   '로',
#   '족발',
#   '못',
#   '먹다',
#   '1',
#   '이다'],
#  ['양', '어마어마하다', '다음', '또', '주문'],
#  ['고기', '양도', '많다', '야들야들하다', '너무', '맛있다', '다음', '또', '시키다'],
#  ['왕왕', '왕', '왕왕', '왕', '왕'],
#  ['음식',
#   '맛있다',
#   '자다',
#   '먹다',
#   '불',
#   '족발',
#   '예상',
#   '대로',
#   '끝맛',
#   '맵다',
#   '근데',
#   '배달',
#   '시',
#   '아무렇다',
#   '연락',
#   '없이',
#   '집앞',
#   '두다',
#   '가다',
#   '1시',
#   '30분',
#   '이나',
#   '지나다',
#   '혹시',
#   '나',
#   '문',
#   '열',
#   '어보',
#   '고',
#   '발견',
#   '막국수',
#   '면',
#   '발도',
#   '불',
#   '고',
#   '족발',
#   '다',
#   '식다'],
#  ['맛있다', '자다', '먹다'],
#  ['불',
#   '족발',
#   '넘다',
#   '맛있다',
#   '함께',
#   '온',
#   '막국수',
#   '넘다',
#   '맛있다',
#   '담',
#   '또',
#   '시키다',
#   '번창'],
#  ['족발', '쫀득쫀', '득', '맛있다', '항상', '자다', '먹다', '감사하다'],
#  ['양도', '진짜', '많다', '배달', '빨리', '오다', '맛있다', '자다', '먹다'],
#  ['맛있다', '리뷰', '까지', '쓰다', '막국수', '사이즈', '업', '너무', '좋다', '것', '같다'],
#  ['맛있다', '먹다'],
#  ['다', '좋다', '다만', '막국수', '더', '많다', '새', '콤', '좋다', '네', '요'],
#  ['진짜',
#   '맛있다',
#   '누리다',
#   '없다',
#   '쫀득',
#   '하고',
#   '고기',
#   '김치',
#   '막국수',
#   '정말',
#   '맛있다',
#   '짜다',
#   '먹다',
#   '막국수',
#   '소스',
#   '마늘',
#   '넉넉하다',
#   '부탁드리다',
#   '넉넉하다',
#   '주다',
#   '진짜',
#   '먹다',
#   '또',
#   '주문'],
#  ['적당하다', '다시', '주문', '해', '볼', '만해', '요'],
#  ['안녕하다', '저', '감사하다'],
#  ['쫄깃', '하고', '맛있다', '먹다', '습', '니당다'],
#  ['리뷰',
#   '보고',
#   '족발',
#   '배달',
#   '시키다',
#   '배달',
# ...
#   '서',
#   '시키다',
#   '이번',
#   '주문',
#   '시',
#   '아쉽다',
#   '점',
#   '배달',
#   '예상',
#   '시간',
#   '70분',
#   '안내',
#   '받다',
#   '기다리다',
#   '90분',
#   '지나다',
#   '도착',
#   '주문',
#   '이후',
#   '비',
#   '오다',
#   '비',
#   '오는',
#   '날',
#   '배송',
#   '기사',
#   '분',
#   '고생',
#   '오래',
#   '걸리다',
#   '감안',
#   '본점',
#   '에서도',
#   '사전',
#   '늦어지다',
#   '연락',
#   '없다',
#   '한창',
#   '배고프다',
#   '와중',
#   '마냥',
#   '기다리다',
#   '되다',
#   '점',
#   '아쉽다'],
#  ['예상', '시간', '보다', '빨리', '오다', '족발', '부드럽다', '맛있다', '양도', '많다'],
#  ['항상', '믿음', '을', '주시', '꽃', '보다', '족발', '화이팅', '이다'],
#  ['맛있다', '족발', '평범하다'],
#  ['쟁반', '국수', '깔끔하다', '맛있다'],
#  ['아주아주', '맛있다', '먹다'],
#  ['배달',
#   '2시간',
#   '넘다',
#   '걸리다',
#   '매장',
#   '전화하다',
#   '주문',
#   '많다',
#   '밀리다',
#   '불친절하다',
#   '답변',
#   '함',
#   '내',
#   '잘못',
#   '줄',
#   '그래도',
#   '배달',
#   '분',
#   '친절하다'],
#  ['1시간', '10분', '정도', '걸리다', '같다', '맛', '잇다', '맛', '잇다', '먹다', '욧'],
#  ['양',
#   '진짜',
#   '많다',
#   '다음',
#   '시키다',
#   '때',
#   '보쌈',
#   '보단',
#   '족발',
#   '을',
#   '많이',
#   '시키다',
#   '족발',
#   '진짜',
#   '맛있다'],
#  ['먹다'],
#  ['까먹다', '먹다', '찍다', '사진', '이다', '맛있다', '먹다'],
#  ['다른',
#   '유명하다',
#   '곳',
#   '시키다',
#   '먹다',
#   '맛있다',
#   '모르다',
#   '여기',
#   '한번',
#   '시키다',
#   '보다',
#   '여기',
#   '진짜',
#   '맛있다',
#   '곳',
#   '이다',
#   '입',
#   '먹다',
#   '다른',
#   '곳',
#   '보다',
#   '맛있다',
#   '확',
#   '느껴지다',
#   '앞',
#   '족발',
#   '꽃',
#   '보다',
#   '족발',
#   '만',
#   '시키다',
#   '예정',
#   '이에요'],
#  ['맛', '나다', '자다', '먹다', '쏴좡님'],
#  ['최고다', '맛있다', '먹다'],
#  ['맛있다', '자주', '시키다', '먹다', '있다'],
#  ['양도', '괜찮다', '맛있다'],
#  ['족발', '막국수', '김치', '다', '맛있다', '김치', '양', '부족하다', '것맘', '아쉽다', '습', '니당다'],
#  ['불',
#   '족발',
#   '제',
#   '생각',
#   '보다',
#   '많이',
#   '맵다',
#   '주의',
#   '배달',
#   '빠르다',
#   '양도',
#   '넉넉하다',
#   '감사하다'],
#  ['맛있다', '푸다', '짐', '1시간', '넘다', '기다리다'],
#  ['맛있다', '자다', '먹다'],
#  ['간만', '만족스럽다', '가계', '찾다'],
#  ['처음', '시키다', '정말', '맛있다', '먹다'],
#  ['정신없이',
#   '먹다',
#   '찍다',
#   '사진',
#   '엉망',
#   '이지만',
#   '족발',
#   '너무',
#   '맛있다',
#   '부모님',
#   '좋아하다',
#   '냉채',
#   '족발',
#   '맛있다',
#   '막국수',
#   '넉넉하다',
#   '주다',
#   '좋다',
#   '담',
#   '또',
#   '시키다'],
#  ['여럿', '이서', '먹다', '양', '충분하다'],
#  ['처음', '시키다', '양도', '많다', '맛', '좋다'],
#  ['동네', '보족', '가게', '묻다', '꽃족', '이라', '답', '하', '라'],
#  ['생각',
#   '보다',
#   '양',
#   '너무',
#   '적다',
#   '하지만',
#   '너무',
#   '맛있다',
#   '막국수',
#   '뿔기',
#   '전',
#   '빨리',
#   '먹다',
#   '야하다'],
#  ['족발', '그냥', '평범하다'],
#  ['족발',
#   '양도',
#   '적당하다',
#   '맛있다',
#   '막',
#   '달다',
#   '않다',
#   '적당하다',
#   '감칠맛',
#   '나다',
#   '김치',
#   '너무',
#   '짜지다',
#   '달다',
#   '않다',
#   '긋다',
#   '긋다',
#   '긋다'],
#  ['이집', '고기', '고소하다'],
#  ['배달', '빠르다', '맛있다', '자다', '먹다', '음료수', '사이', '즈', '업', '주다', '고맙다'],
#  ['밤늦다',
#   '야식',
#   '땡기다',
#   '시키다',
#   '진짜',
#   '초',
#   '대박',
#   '헝헝',
#   '먹다',
#   '죽다',
#   '그냥',
#   '불금',
#   '제대로',
#   '달다',
#   '보다',
#   '콜라',
#   '크다',
#   '쌈',
#   '많이',
#   '달라',
#   '고',
#   '쌈',
#   '먹다',
#   '행복하다',
#   '죽',
#   '을',
#   '지경',
#   '덕분',
#   '행복하다',
#   '야식',
#   '이다'],
#  ['맛있다', '쌈', '많이', '주다', '감사하다'],
#  ['너무', '맛있다', '냄새', '안나', '고'],
#  ['양', '많다', '맛있다'],
#  ['막국스',
#   '사이즈',
#   '업',
#   '안되다',
#   '같다',
#   '요청',
#   '사항',
#   '안',
#   '보다',
#   '같다',
#   '일단',
#   '맛있다',
#   '먹다'],
#  ['너무',
#   '맛',
#   '잇다',
#   '진짜',
#   '족발',
#   '보쌈',
#   '매',
#   '일',
#   '여기',
#   '만',
#   '시키다',
#   '먹다',
#   '오',
#   '짱',
#   '빵맨'],
#  ['동생',
#   '일반',
#   '족발',
#   '을',
#   '먹다',
#   '싶다',
#   '제',
#   '불족',
#   '먹다',
#   '반',
#   '반',
#   '주문',
#   '꽃족',
#   '역시',
#   '라는',
#   '말',
#   '밖에',
#   '안',
#   '나오다',
#   '리뷰',
#   '이벤트',
#   '로',
#   '주신',
#   '대왕',
#   '막국수',
#   '감사하다',
#   '닷',
#   '또',
#   '주문',
#   '요청',
#   '사항',
#   '늘',
#   '감사하다'],
#  ['음식',
#   '따뜻하다',
#   '포장',
#   '깔끔하다',
#   '자다',
#   '도착',
#   '구성',
#   '좋다',
#   '무엇',
#   '보다',
#   '고기',
#   '정말',
#   '맛있다',
#   '꽃족',
#   '만',
#   '시키다',
#   '먹다',
#   '습',
#   '니당다'],
#  ['너무',
#   '너무',
#   '너무',
#   '맛있다',
#   '막국수',
#   '사이즈',
#   '보고',
#   '깜짝',
#   '놀라다',
#   '족발',
#   '불',
#   '족도',
#   '존맛',
#   '탱'],
#  ['오늘',
#   '시키다',
#   '먹다',
#   '배달',
#   '빠르다',
#   '항상',
#   '만족스럽다',
#   '네',
#   '여',
#   '조만간',
#   '또',
#   '먹다',
#   '거',
#   '에여'],
#  ['족발', '진짜', '맛있다', '항상', '자다', '먹다', '다음', '또', '주문'],
#  ['쫄깃쫄깃', '탱글탱글', '맛있다'],
#  ['살다',
#   '살다',
#   '이렇게',
#   '맛없다',
#   '족발',
#   '처음',
#   '이에요',
#   '입맛',
#   '까다롭다',
#   '편도',
#   '아니다',
#   '남',
#   '맛있다',
#   '다',
#   '맛있다',
#   '입맛',
#   '이에요',
#   '근데',
#   '완전',
#   '질',
#   '기고',
#   '냄새',
#   '나다',
#   '양도',
#   '많다',
#   '그렇다',
#   '않다',
#   '막국수',
#   '진짜',
#   '맛없다',
#   '사이다',
#   '제일',
#   '맛있다',
#   '진짜',
#   '후기',
#   '속',
#   '았',
#   '어',
#   '요',
#   '너무',
#   '실망',
#   '이에요',
#   '정말로'],
#  ['전체', '적', '맛있다', '특히', '막국수', '맛있다', '먹다', '둘', '먹기', '딱', '좋다'],
#  ['전체',
#   '적',
#   '나쁘다',
#   '않다',
#   '배달',
#   '생각',
#   '보다',
#   '빨르다',
#   '깔끔하다',
#   '족발',
#   '우와',
#   '맛있다',
#   '느낌',
#   '아니다',
#   '무난'],
#  ['양', '정말', '미치다', '맛있다'],
#  ['항상', '맛있다', '먹다'],
#  ['오늘',
#   '맛있다',
#   '양도',
#   '풍',
#   '성',
#   '맛',
#   '쫀득쫀득',
#   '야채',
#   '막국수',
#   '많다',
#   '맛있다',
#   '막국수',
#   '소스',
#   '전보',
#   '다',
#   '더',
#   '맛있다',
#   '맛',
#   '점점',
#   '업그레이드',
#   '되다',
#   '같다'],
#  ['맛있다', '살', '먹다', '습', '니당다'],
#  ['항상', '시키다', '먹다', '막국수', '정말', '맛있다'],
#  ['배달',
#   '빨르다',
#   '음식',
#   '두',
#   '맛있다',
#   '족발',
#   '여기',
#   '서다',
#   '먹다',
#   '않다',
#   '가격',
#   '구성',
#   '맛',
#   '제일',
#   '만족하다',
#   '집',
#   '이에요'],
#  ['족발', '진짜', '맛있다', '맨날', '먹다', '맛', '이네', '요', '감사하다'],
#  ['엄청',
#   '오랜',
#   '만',
#   '주문',
#   '역시',
#   '나',
#   '맛있다',
#   '요새',
#   '바쁘다',
#   '못',
#   '시키다',
#   '먹다',
#   '자주',
#   '시키다',
#   '먹다',
#   '역시',
#   '꽃족'],
#  ['반',
#   '이상아',
#   '비계',
#   '에요',
#   '보쌈',
#   '실패',
#   '이다',
#   '양은',
#   '많다',
#   '막다',
#   '맛있다',
#   '근데',
#   '메인',
#   '아니다',
#   '그래서',
#   '다시다',
#   '안',
#   '시키다',
#   '먹다',
#   '구',
#   '요',
#   '배달',
#   '예상',
#   '시간',
#   '보다',
#   '늦다'],
#  ['먹다', '상추', '싱싱하다', '좋다'],
#  ['배달',
#   '빠르다',
#   '냄새',
#   '안나',
#   '고',
#   '부드럽다',
#   '맛있다',
#   '양도',
#   '다르다',
#   '비',
#   '많다',
#   '약간',
#   '덜',
#   '짜다',
#   '완전',
#   '긋다'],
#  ['가격', '대비', '양', '많다'],
#  ['넘다', '맛있다', '양도', '적당하다'],
#  ['고기',
#   '맛',
#   '나다',
#   '양도',
#   '많다',
#   '냉면',
#   '쬐다',
#   '끄다',
#   '제',
#   '스타일',
#   '아니다',
#   '그래도',
#   '별',
#   '4',
#   '개다',
#   '아깝다',
#   '않다'],
#  ['두번째',
#   '주문',
#   '예요',
#   '쫀득쫀득',
#   '족발',
#   '맛',
#   '매콤',
#   '막국수',
#   '까지',
#   '양도',
#   '많다',
#   '맛',
#   '좋다'],
#  ['양도',
#   '많다',
#   '맛',
#   '나다',
#   '자다',
#   '먹다',
#   '습',
#   '니',
#   '댜',
#   '이벤트',
#   '막국수',
#   '사이즈',
#   '업',
#   '사장',
#   '님',
#   '감사하다'],
#  ['소',
#   '짜다',
#   '시키다',
#   '양',
#   '3',
#   '4',
#   '인분',
#   '같다',
#   '진짜',
#   '많다',
#   '배달',
#   '두',
#   '빠르다',
#   '맛있다',
#   '양도',
#   '많다',
#   '자다',
#   '먹다'],
#  ['족발', '깔끔하다', '맛있다', '양도', '적당하다', '김치', '맛있다', '상추', '신선하다', '좋다'],
#  ['족발',
#   '뿐',
#   '아니다',
#   '막국수',
#   '장인',
#   '시',
#   '네',
#   '요',
#   '진짜',
#   '푸다',
#   '지다',
#   '배',
#   '터지다',
#   '자다',
#   '먹다',
#   '흥'],
#  ['늘', '맛', '나다', '먹다', '최고'],
#  ['맛있다', '3', '번째', '주문', '이네', '요', '직접', '매장', '가다', '먹다', '보다'],
#  ['족발', '이집', '최고', '인', '듯'],
#  ['배달', '빠르다', '제일', '맛있다', '감사하다'],
#  ['맛있다', '먹다', '막국수', '불지', '않다', '새', '콤달콤', '맛있다'],
#  ['사진', '을', '못', '찍다', '진짜', '맛있다', '자다', '먹다'],
#  ['사진', '을', '못', '찍다', '맛있다', '먹다'],
#  ['맛있다',
#   '배달',
#   '빠르다',
#   '두번째',
#   '시키다',
#   '먹다',
#   '저번',
#   '부터',
#   '느끼다',
#   '막국수',
#   '진짜',
#   '맛있다',
#   '친구',
#   '맛있다',
#   '좋아하다',
#   '또',
#   '시키다'],
#  ['확실하다', '사장', '님', '리뷰', '하나', '하', '나', '일일', '이다', '보시', '나', '보다'],
#  ['항상', '맛있다', '항상', '시키다', '먹다'],
#  ['자다', '먹다', '다음', '또', '시키다'],
#  ['덜다', '먹다', '그런데', '양은', '훨씬', '많다', '읍니', '다'],
#  ['자다', '먹다', '배달', '빠르다', '맛', '소', '소'],
#  ['처음',
#   '엔',
#   '양',
#   '부족',
#   '해보다',
#   '먹다',
#   '보다',
#   '양',
#   '많다',
#   '알다',
#   '다른',
#   '곳들뵤',
#   '다',
#   '저렴하다',
#   '막국수',
#   '같이',
#   '주다',
#   '다음',
#   '꼬',
#   '시키다',
#   '먹다',
#   '의향',
#   '있다'],
#  ['어머니', '너무', '좋다'],
#  ['맛있다', '자다', '먹다'],
#  ['양도',
#   '진짜',
#   '많다',
#   '맛있다',
#   '매다',
#   '앞',
#   '불족',
#   '여기',
#   '서',
#   '만',
#   '시키다',
#   '먹다',
#   '구',
#   '요',
#   '배달',
#   '빨리',
#   '오다',
#   '기사',
#   '님',
#   '친절하다',
#   '먹다',
#   '감사하다'],
#  ['양도', '푸다', '짐', '하고', '맛있다', '자다', '먹다'],
#  ['맛있다', '먹다'],
#  ['비',
#   '오는',
#   '날',
#   '이라',
#   '배달',
#   '시키다',
#   '죄송하다',
#   '암튼',
#   '여기다',
#   '족발',
#   '야들야들',
#   '쫀득쫀득',
#   '변하다',
#   '없이',
#   '맛있다',
#   '막국수',
#   '거의',
#   '미치다',
#   '맛',
#   '막국수',
#   '서비스',
#   '감사하다',
#   '미치다',
#   '먹다',
#   '사진',
#   '을',
#   '늦다',
#   '찍다'],
#  ['양', '엄청', '많다'],
#  ['맛있다', '자다', '먹다'],
#  ['맛있다', '양도', '적당', '하지만', '배달', '많이', '파다'],
#  ['두번째', '주문', '이다', '먹다'],
#  ['맛있다',
#   '먹다',
#   '배달',
#   '빠르다',
#   '양도',
#   '많다',
#   '맛',
#   '좋다',
#   '남자',
#   '3',
#   '명',
#   '이서',
#   '먹다',
#   '배부르다',
#   '조금',
#   '남',
#   '을',
#   '정도',
#   '네',
#   '요'],
#  ['불족',
#   '꽃',
#   '보다',
#   '족발',
#   '갑',
#   '이다',
#   '먹다',
#   '먹다',
#   '질리',
#   '지',
#   '않다',
#   '신의한수',
#   '배달',
#   '50분',
#   '에서',
#   '30분',
#   '만에',
#   '왓네',
#   '요',
#   '사장',
#   '님',
#   '친절하다',
#   '배달',
#   '분도',
#   '엄청',
#   '친절하다',
#   '강',
#   '추하다'],
#  ['양도', '만족스럽다', '음식', '맛', '정말', '만족스럽다'],
#  ['적당', '매촘', '하고', '맛', '좋다', '야채', '넣다', '맛있다', '먹다'],
#  ['맛있다', '항상', '시키다'],
#  ['가다',
#   '집',
#   '에서도',
#   '시키다',
#   '먹다',
#   '종종',
#   '들다',
#   '포장',
#   '오늘',
#   '막국수',
#   '사이즈',
#   '업',
#   '받다',
#   '기분',
#   '좋다',
#   '맛있다',
#   '먹다',
#   '사진',
#   '리뷰',
#   '남다',
#   '보쌈',
#   '고기',
#   '영',
#   '아니다',
#   '걸',
#   '먹다',
#   '가다',
#   '준',
#   '건지다',
#   '파다',
#   '남다',
#   '모으다',
#   '보내다',
#   '고기',
#   '에서',
#   '냄새',
#   '나다',
#   '질',
#   '기고',
#   '비주',
#   '얼다',
#   '꽝',
#   '찾아가다',
#   '말다'],
#  ['세번',
#   '째',
#   '주문',
#   '인데',
#   '오늘',
#   '불족',
#   '중간',
#   '중간',
#   '오래되다',
#   '맛',
#   '이나',
#   '늘다',
#   '섞이다',
#   '거',
#   '빼다',
#   '양',
#   '이나',
#   '맛',
#   '이나',
#   '다',
#   '좋다',
#   '배달',
#   '30분',
#   '만에왔구요'],
#  ['맛있다', '먹다', '슴', '니', '다'],
#  ['양도', '적당하다', '배달', '음식', '답지', '않다', '심심하다', '배달', '빨르다'],
#  ['맛있다', '추천'],
#  ['맛있다',
#   '먹다',
#   '족발',
#   '촉촉하다',
#   '부드럽다',
#   '막국수',
#   '사이드',
#   '반찬',
#   '까지',
#   '간이',
#   '너무',
#   '맛있다',
#   '밉다',
#   '간',
#   '주름',
#   '하나',
#   '늘다',
#   '채소',
#   '싱싱하다',
#   '마음',
#   '들다',
#   '다음',
#   '또',
#   '시키다'],
#  ['맛있다', '먹다', '중', '인데', '적다', '대자', '시키다', '보다'],
#  ['족발', '맛있다', '막국수', '맛있다'],
#  ['맛있다', '자다', '먹다', '포장', '깔끔하다', '맛', '좋다'],
#  ['몇번',
#   '째',
#   '배달',
#   '먹다',
#   '진짜',
#   '너무',
#   '맛있다',
#   '근데',
#   '오늘',
#   '고',
#   '기',
#   '맛',
#   '너무',
#   '냄새',
#   '나서다',
#   '실망',
#   '대다',
#   '실망',
#   '반도',
#   '못',
#   '먹다',
#   '버리다',
#   '왜',
#   '그렇다',
#   '요',
#   '쟁반',
#   '국수',
#   '존맛',
#   '인데',
#   '고기',
#   '또',
#   '시키다',
#   '먹다',
#   '되다',
#   '싶다'],
#  ['너무', '너무', '만족', '스럽게', '자다', '먹다', '고기', '김치', '막국수', '좋다'],
#  ['전',
#   '뜨겁다',
#   '촉촉하다',
#   '족발',
#   '을',
#   '좋아하다',
#   '그런',
#   '스탈',
#   '아니다',
#   '식다',
#   '쫄깃힐',
#   '느낌',
#   '이라',
#   '아쉽다',
#   '다른',
#   '서브',
#   '반찬',
#   '이나',
#   '이렇다',
#   '많다',
#   '치다',
#   '않다',
#   '도용',
#   '그런데',
#   '김치',
#   '나',
#   '막국수',
#   '먹다',
#   '엇시',
#   '유'],
#  ['맛있다', '감사하다'],
#  ['맛있다', '양도', '많다', '감사하다'],
#  ['족발',
#   '중',
#   '로',
#   '시키다',
#   '양',
#   '많다',
#   '둘이서',
#   '다',
#   '못',
#   '먹다',
#   '다음',
#   '날',
#   '까지',
#   '먹다',
#   '배',
#   '고프다',
#   '입',
#   '먹다',
#   '정신없이',
#   '먹다',
#   '사진',
#   '못',
#   '찍다',
#   '다음',
#   '찍다',
#   '겠다',
#   '김치',
#   '딱',
#   '간',
#   '맞다',
#   '좋다'],
#  ['양', '배달', '만', '모두', '만족', '만족', '만', '만족'],
#  ['맛있다', '습', '니당다', '리뷰', '이벤트', '막국수', '사이', '즈', '업', '되다', '배부르다', '먹다'],
#  ['진짜', '최고', '애용', '족발', '두다', '여기', '서'],
#  ['맛있다', '다음', '또', '시키다', '먹다'],
#  ['생각',
#   '맛',
#   '별로',
#   '에요',
#   '겉',
#   '껍질앙념',
#   '너무',
#   '짜다',
#   '고기',
#   '양념',
#   '안',
#   '돼다',
#   '싱겁다',
#   '고기',
#   '썰다',
#   '제대',
#   '르',
#   '안',
#   '썰다',
#   '붙다',
#   '먹기',
#   '불편하다',
#   '막국수',
#   '양도',
#   '별로',
#   '에요',
#   '양념',
#   '맛',
#   '약하다'],
#  ['맛있다', '먹다'],
#  ['맛있다', '또', '시키다', '먹다', '의사', '있다'],
#  ['양도', '많다', '맛있다'],
#  ['맛있다', '고기', '부드럽다'],
#  ['친절하다', '족발', '맛있다'],
#  ['맛있다', '담', '또', '시키다', '막다', '막국수', '양', '많다'],
#  ['아주아주', '맛있다', '막국수', '양', '엄청', '많다', '고기', '맛', '나다'],
#  ['맛있다', '먹다', '배달', '예상', '시간', '보다', '더', '빨리', '오다', '감사하다'],
#  ['소', '짜다', '뼈', '말다', '커서', '고기', '적다', '보이다'],
#  ['막국수',
#   '사이즈',
#   '업',
#   '엄청',
#   '크다',
#   '주시',
#   '고',
#   '배달',
#   '빠르다',
#   '상추',
#   '넉넉하다',
#   '달라',
#   '고',
#   '얘기',
#   '봉지',
#   '더',
#   '넣다',
#   '놀라다',
#   '맛있다',
#   '꼭',
#   '들다',
#   '보다'],
#  ['양도',
#   '많다',
#   '맛',
#   '좋다',
#   '배달',
#   '예',
#   '정시',
#   '간',
#   '보다',
#   '빨리',
#   '올',
#   '정도',
#   '로',
#   '신속하다',
#   '가족',
#   '3',
#   '인',
#   '모두',
#   '아주',
#   '만족하다'],
#  ['맛', '잇다', '먹다', '만족하다'],
#  ['맛있다', '먹다', '양', '조금', '더', '많다', '좋다'],
#  ['사진', '없다', '맛있다'],
#  ['돼지고기', '잡다', '나다', '배달', '기사', '님', '친절하다'],
#  ['가격',
#   '저렴하다',
#   '거기',
#   '다가',
#   '맛있다',
#   '거기',
#   '다가',
#   '양도',
#   '푸다',
#   '짐',
#   '하고',
#   '기',
#   '막히다',
#   '배달',
#   '빠르다',
#   '정말',
#   '행복하다',
#   '먹다'],
#  ['처음',
#   '먹다',
#   '정말',
#   '맛있다',
#   '배달',
#   '원',
#   '분도',
#   '친절하다',
#   '양도',
#   '많다',
#   '다',
#   '좋다',
#   '다음',
#   '또',
#   '주문'],
#  ['양', '많다', '부드럽다', '차다', '맛있다'],
#  ['고기',
#   '잡다',
#   '하나',
#   '없이',
#   '정말',
#   '부드럽다',
#   '막국수',
#   '야채',
#   '음료',
#   '구성',
#   '알차다',
#   '배',
#   '터지다',
#   '먹다',
#   '별',
#   '다섯',
#   '개',
#   '꽉꽉',
#   '채우다',
#   '드리다'],
#  ['배달', '예상', '보다', '일찍', '서다', '넘다', '좋다'],
#  ['족발', '너무', '짜다', '먹기', '힘들다'],
#  ['막국수', '너무', '맛있다', '마늘', '많이', '주다', '감사하다', '족발', '옴청', '맛', '나', '요'],
#  ['양도', '많다', '맛있다'],
#  ['여기', '만', '시키다', '먹다', '굿굿'],
#  ['족발', '오랜', '만', '맛있다', '먹다', '가족', '같이', '먹다', '다', '들다', '만족하다'],
#  ['불족',
#   '을',
#   '좋아하다',
#   '불족',
#   '별',
#   '루',
#   '인',
#   '듯',
#   '요',
#   '너무',
#   '퍽퍽',
#   '살',
#   '만',
#   '있다',
#   '맛',
#   '보다는',
#   '퍽퍽살',
#   '때문',
#   '별',
#   '루',
#   '인',
#   '듯',
#   '요'],
#  ['진짜', '양', '정말', '많다', '맛', '최고', '에요'],
#  ['배달',
#   '정말',
#   '빨',
#   '라서',
#   '좋다',
#   '양도',
#   '적당하다',
#   '맛있다',
#   '막국수',
#   '김치',
#   '다',
#   '맛있다',
#   '다음',
#   '또',
#   '시키다',
#   '먹다',
#   '보다'],
#  ['대', '만족', '여러', '군데', '고민', '시키다', '선택', '성공', '적'],
#  ['맛있다', '먹다', '최고', '최고'],
#  ['맛있다', '자다', '먹다', '부드럽다', '맛있다'],
#  ['단골',
#   '이에요',
#   '맛',
#   '넘다',
#   '맛있다',
#   '가성',
#   '비',
#   '쵝',
#   '오입',
#   '니',
#   '다',
#   '역시',
#   '족발',
#   '보쌈',
#   '맛집',
#   '인정'],
#  ['맛있다'],
#  ['너무', '깔끔하다', '맛있다', '양도', '많다', '단점', '을', '찾다', '없다'],
#  ['맛', '나다', '자다', '먹다', '담', '또', '주문'],
#  ['맛있다', '막국수', '엄청', '많다'],
#  ['쟁반',
#   '막국수',
#   '고기',
#   '조합',
#   '자다',
#   '어울리다',
#   '가격',
#   '부담',
#   '만',
#   '없다',
#   '자주',
#   '시키다',
#   '먹다',
#   '싶다',
#   '여기다',
#   '이미',
#   '즐겨찾기',
#   '주문',
#   '하고',
#   '있다',
#   '배고프다',
#   '사진',
#   '이고',
#   '뭐',
#   '고',
#   '그냥',
#   '먹다',
#   '정신',
#   '팔다',
#   '다',
#   '먹다',
#   '자다',
#   '먹다'],
#  ['처음', '시키다', '먹다', '맛있다'],
#  ['매번', '맛있다', '자다', '먹다'],
#  ['처음', '시키다', '먹다', '맛있다', '영'],
#  ['너무', '맛있다', '담', '또', '시키다', '먹다'],
#  ['배달', '엄청', '빨르다', '맛', '이랑', '양도', '많다', '좋다'],
#  ['푸다', '지다', '자다', '먹다', '감사하다'],
#  ['맛있다', '조금', '짜다', '아쉽다'],
#  ['여기',
#   '진짜',
#   '맛',
#   '나',
#   '요',
#   '가격',
#   '대비',
#   '양도',
#   '푸다',
#   '짐',
#   '하고',
#   '애',
#   '좋아하다',
#   '유명하다',
#   '보다',
#   '더',
#   '맛있다'],
#  ['양', '정말', '많다', '소자', '시키다', '맛있다'],
#  ['두번째',
#   '주문',
#   '이네',
#   '요',
#   '이번',
#   '엔',
#   '사이',
#   '즈',
#   '업',
#   '이벤트',
#   '있다',
#   '맛',
#   '역시',
#   '좋다',
#   '배부르다',
#   '맛있다',
#   '자다',
#   '먹다'],
#  ['양도', '많다', '부드럽다', '맛있다', '항상', '시키다', '먹다', '곳', '이다'],
#  ['맛', '있다', '양', '생각', '것', '보다', '적다'],
#  ['먹다'],
#  ['문',
#   '연',
#   '곳',
#   '중',
#   '제일',
#   '나',
#   '아보',
#   '여서',
#   '시키다',
#   '막국수',
#   '랑',
#   '족발',
#   '맛있다',
#   '고기',
#   '지다',
#   '지도',
#   '않다'],
#  ['넘흐',
#   '맛있다',
#   '가격',
#   '저렴하다',
#   '야채',
#   '많이',
#   '주시',
#   '고',
#   '배달',
#   '빠르다',
#   '서비스',
#   '좋다',
#   '그렇다',
#   '습',
#   '니',
#   '닷'],
#  [],
#  ['최근',
#   '족발',
#   '항상',
#   '여기',
#   '서',
#   '만',
#   '시키다',
#   '너무',
#   '짜지다',
#   '달다',
#   '않다',
#   '맛있다',
#   '먹다',
#   '있다',
#   '막국수',
#   '서비스',
#   '까지',
#   '아주',
#   '좋다'],
#  ['정말', '맛있다', '먹다'],
#  ['흔하다', '먹다', '족발', '맛', '약간', '짜다', '느낌', '있다'],
#  ['맛있다', '먹다'],
#  ['보쌈', '처음', '시키다', '보다', '생각', '보다', '괜찮다', '항상', '믿다', '먹다'],
#  ['족발', '너무', '맛있다', '막국수', '맛있다', '배달', '빠르다', '진짜', '다음', '또', '주문', '감사하다'],
#  ['양도',
#   '많다',
#   '맛',
#   '정말',
#   '맛있다',
#   '잡다',
#   '안나',
#   '고',
#   '정말',
#   '맛있다',
#   '먹다',
#   '개인',
#   '적',
#   '불',
#   '족발',
#   '진짜',
#   '맛있다',
#   '다음',
#   '번',
#   '에도',
#   '시키다',
#   '먹다',
#   '규',
#   '요'],
#  ['족발',
#   '먹다',
#   '싶다',
#   '때',
#   '여기',
#   '만',
#   '시키다',
#   '배달',
#   '예상',
#   '보다',
#   '엄청',
#   '빨리',
#   '오다',
#   '뜨끈하다',
#   '달달',
#   '족발',
#   '엄청나다',
#   '양',
#   '상추',
#   '늘',
#   '만족스럽다',
#   '다음',
#   '또',
#   '주문'],
#  ['맛있다', '먹다'],
#  ['리뷰',
#   '처음',
#   '쓰다',
#   '별하나',
#   '아깝다',
#   '지금',
#   '어제',
#   '밤',
#   '그거',
#   '먹다',
#   '계속',
#   '설사',
#   '중',
#   '이에요',
#   '궁서체',
#   '이다',
#   '뭐',
#   '문제',
#   '이다',
#   '족발',
#   '막국수',
#   '전부',
#   '다',
#   '맛',
#   '별로',
#   '여서',
#   '다',
#   '남기다',
#   '여태',
#   '아무',
#   '것',
#   '못',
#   '먹다',
#   '설사',
#   '중',
#   '인데',
#   '어떻다',
#   '배달',
#   '40분',
#   '소요',
#   '라고',
#   '선',
#   '시간',
#   '더',
#   '걸리다',
#   '요'],
#  ['배달', '빠르다', '맛', '좋다'],
#  ['너무', '맛있다', '자다', '먹다'],
#  ['족발', '보쌈', '맛', '잇다', '양도', '굿'],
#  ['너무',
#   '맛있다',
#   '받다',
#   '나서다',
#   '허겁지겁',
#   '먹다',
#   '제대로',
#   '되다',
#   '음식사진',
#   '없다',
#   '클리어',
#   '막국수',
#   '사진',
#   '맛',
#   '을',
#   '보증'],
#  ['배달',
#   '시키다',
#   '지다',
#   '삼십분',
#   '만에',
#   '오다',
#   '양도',
#   '많다',
#   '맛있다',
#   '어머니',
#   '께서',
#   '특히',
#   '따뜻하다',
#   '좋아하다',
#   '배달',
#   '시키다',
#   '차갑다',
#   '오다',
#   '곳',
#   '많다',
#   '여기다',
#   '따뜻하다',
#   '좋다',
#   '습',
#   '니당다',
#   '상추',
#   '랑',
#   '채소',
#   '소스',
#   '넉넉하다',
#   '주시',
#   '고',
#   '막국수',
#   '랑',
#   '김치',
#   '고',
#   '정말',
#   '맛있다',
#   '부모님',
#   '단골',
#   '맛있다',
#   '자다',
#   '들다'],
#  ['배달', '빨리', '오다', '족발', '맛있다', '먹다', '추천'],
#  ['족발', '항상', '여기', '서', '시키다', '먹다', '너무', '맛있다'],
#  ['맛', '나다', '자다', '먹다', '습', '니당다'],
#  ['글쎄요',
#   '개인',
#   '취향',
#   '인가요',
#   '리뷰',
#   '보고',
#   '주문',
#   '맛',
#   '중요하다',
#   '저',
#   '에겐',
#   '제',
#   '알다',
#   '냉채',
#   '족발',
#   '소스',
#   '약하다',
#   '쟁반',
#   '막국수',
#   '평범',
#   '미달',
#   '이네',
#   '요',
#   '재',
#   '주문',
#   '못',
#   '죄송',
#   '요'],
#  ['맛있다', '빠르다', '강추'],
#  ...]

# %%
document_embedding_list = []

for idx,review in enumerate(test_tokenized_data):
    doc2vec = None
    cnt=0
    for word in review:
        if word in model.wv.vocab:
            cnt+=1
            if doc2vec is None:
                doc2vec= model.wv.__getitem__(word)
            else:
                doc2vec= doc2vec+ model.wv.__getitem__(word)
        
    if doc2vec is not None:
            
        doc2vec=doc2vec/cnt
        
    
    else:
        print(review,idx)
        doc2vec=np.zeros(100,)
        
    document_embedding_list.append(doc2vec)
# Out:
# [] 53
# [] 339
# [] 383
# [] 979
# [] 1014
# [] 1170
# [] 1381
# [] 1775

# %%
np.zeros(100,).shape
# Out:
# (100,)

# %%
cosine_similarities = cosine_similarity(document_embedding_list, document_embedding_list)

# %%
len(document_embedding_list)
# Out:
# 2026

# %%
cosine_similarities[1][1189]
# Out:
# 0.942387307761204

# %%
cosine_similarities[339]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
j=93
sim_score=list(enumerate(cosine_similarities[j]))
sim_score=sorted(sim_score,key=lambda x:x[1],reverse=True)
sim_reivew_idx=[i for i in sim_score[1:50]]

print(f'현재 리뷰 : ',test.review_customer.values[j])

for i in sim_reivew_idx:
    print(f'유사리뷰 {i} : ',test.review_customer.values[i[0]])
# Out:
# 현재 리뷰 :  맛있어서 포장뜯자마자 순삭이라 사진이없어서 안타깝네요.....맛있게 잘 먹었습니다
# 유사리뷰 (1910, 0.9421355433792444) :  포장 뜯지도 않고 사진 먼저 찍었네요^^ 맛있게 잘 먹었습니다
# 유사리뷰 (993, 0.9331700578978046) :  너무 맛있어서 받고 나서 허겁지겁 먹느라고 제대로된 음식사진이 없네용ㅋㅋㅋ 클리어한 막국수 사진으로 맛을 보증하겠습니다ㅋㅋㅋ!!
# 유사리뷰 (511, 0.9211851515898566) :  저번에먹었을때보다 쟁반국수가
# 훨~~~씬 맛있어 져서 진짜 맛있게 먹었네요
# 고기는 원래 맛있구요^^
# 덕분에 너무 맛있게 푸짐하게 잘 먹었지만
# 배가 많이 고파서 사진을 찍을생각도 못하고
# 정신없이 먹었어요;;;
# 담에 주문하면 사진과함께 리뷰 올리겠습니다!!!!
# 유사리뷰 (1494, 0.9152220058180345) :  배고팠는데 배달도 빨리와서 허겁지겁 먹어서 다먹고 사진을 못찍었네요.. 항상 애용합니당 막국수가 더맛있어졌어요!
# 유사리뷰 (790, 0.914827677615009) :  배고파서 먹는도중에 찍었네요!!
# 맛있게 잘 먹었습니다!!!
# 유사리뷰 (835, 0.9128817612386652) :  정신없이 먹다 찍어서 사진이 좀 엉망이지만 족발 너무 맛있다고 부모님 좋아하셨어요~  냉채족발도 맛있었구요~  막국수도 넉넉히 주셔서 좋았어요~
# 담에 또 시킬께요~~
# 유사리뷰 (883, 0.9110540193756838) :  사진을 못찍었는데 진짜 맛있게 잘 먹었습니다
# 유사리뷰 (646, 0.9097444569768997) :  정신없이.먹느라 사진을 못찍었어요
# 정말 맛있게 잘~~~~먹었습니다^^
# 족발을 잘 안먹는 언니가 정말 맛있게 먹었다고
# 가게이름까지 물어보더라구요
# 담에 또 주문해서 먹을께요^^
# 사이즈업 막국수도 감사히 잘 먹었습니다~~~
# 유사리뷰 (437, 0.9095239880822886) :  오늘 말복이라 뭐 먹을까 고민하다가 족발 안 먹은지 한참되서 시켰어요 처음 주문하는곳이라 큰 기대는 안하고 주문했는데 배달해 주신 기사님부터 정말로 너무 친절 하시고 느낌이 좋았습니다 느낌은 적중
# 너무 너무 맛있게 잘 먹었습니다 제가 뼈에 붙은 고기까지 먹었다니까요 ㅋ
# 죄송해요 사진을 못찍었어요 담에 시킬땐 꼭 사진 리뷰 할께요 사장님 맛있게 잘 먹었습니다~~
# 유사리뷰 (41, 0.9077462674970559) :  맛있게 잘 먹었습니다.
# 다먹고 사진을 찍었네요...
# 유사리뷰 (657, 0.9044862820139924) :  맛있게 잘 먹었어요~~~ 5살 아들도 너무 맛있게 먹어서 또 주문하려고요.!  먹느라 사진을 못 찍었네요ㅜㅜ
# 유사리뷰 (359, 0.9041006777861436) :  사진을 못찍었네요 ㅠㅠ 맛있게 잘 먹었어요
# 유사리뷰 (484, 0.9036927445163341) :  너무 배고파 급하게 먹느라 사진은 못찍었지만
# 역시나 양도많고 쟁반국수 사이즈가 어마어마해서 나눠먹어도 남았네요. 번창하세요~
# 유사리뷰 (356, 0.9011161434569982) :  너무 빨리 먹어서 사진을 못찍었네요.. 가족이랑 같이 맛있게 먹었습니다! 배달해주신 분도 너무 친절하셨어요 ㅎㅎㅎ
# 유사리뷰 (963, 0.9004834604510888) :  쟁반막국수와 고기의 조합이 잘 어울려요.
# 가격부담만 없으면 자주 시켜먹고 싶어요.
# 여기는 이미 즐겨찾기 해놓고 주문하고 있어요.
# 배고파서 사진이고 뭐고 그냥 먹는데 정신 팔려서...
# 다 먹고 잘 먹었습니다~
# 유사리뷰 (1860, 0.8996411891682277) :  막국수가 너무 제스타일이네요~
# 보쌈도 물론맛있어용
# 사진은 너무배고파 빨리먹느라 못찍었네요 ㅠㅠ
# 유사리뷰 (1841, 0.8995486695060572) :  먹다찍었네요
# 정말 맛있어서 사진찍는걸 깜빡했어요
# 진짜맛있게 잘 먹었습니다
# 유사리뷰 (640, 0.8980902839190992) :  족발은 냄새도 안나고 맛있게 먹었습니다 근데 막국수는 오자마자 바로 먹질 않아서 그랬는지
# 그냥 패스 했습니다~사진을 못찍어 아쉽네요
# 유사리뷰 (420, 0.897441181430226) :  맛있고 양많은 사람 둘이서 배부르게 먹을정도 양이에요 리뷰이벤트로 막국수도 사이즈업해주셔서 맛있게 잘 먹었습니당 사진은 오자마자 급하게 먹다가 찍어서 좀 없어보이네용;;;
# 유사리뷰 (823, 0.8969421411549455) :  까먹고 먹다가 찍은사진입니다
# 맛있게 잘먹었어요~~
# 유사리뷰 (1658, 0.8962216208000678) :  냉채족발 일단 담겨진게 너무 예쁘구요 야채구성이랑 맛도 너무 좋아요! 추석이라그런가 리뷰 서비스는 못받았지만 만족해서 리뷰남기고 또 시켜먹을거에요!!김치국물 조금 샌거랑 배달하시는분이 잘 못찾아와서 별한개는 뺏습니당
# 유사리뷰 (1589, 0.8954850021736168) :  넘 배고파서 사진 안 찍고 거의 다 먹다가 생각났어요ㅠㅠㅠ진짜 맛있었어요!
# 유사리뷰 (273, 0.8949082463887854) :  고기 잡내도 안나고 너무 맛있습니다 ㅜㅜ 허겁지겁먹다가 사진찍었어요! 종종 시켜먹을거같습니다~
# 유사리뷰 (599, 0.8944505175553128) :  와우 진짜 맛있습니다.
# 족발은 이제 고정해야겠어요
# 누린내하나없고 짭쪼름고소쫄깃
# 향도좋고 둘이서 중자 항상 다못먹는데
# 개눈감추듯 먹어치웠습니다.
# 마늘도 넉넉히주시고 정말잘먹었습니다
# 또주문할께용
# 유사리뷰 (1567, 0.8935193361098902) :  너무너무 맛있었습니다. 중자 시켰는데 두명이서 먹고 배불러서 좀 남겼어요! 고기완전 쫀득쫀득 두툼하고 맛있었습니다! 막국수 봉지 손으로 뜯다가 옷에 다 묻어서 정신없느라 사진이 없네요 ㅠㅠ
# 유사리뷰 (173, 0.893288638036317) :  배가 고파서 다 먹고나니 사진이 없네요....
# 하지만 맛있습니다
# 꼭 주문하세요
# 유사리뷰 (162, 0.8929736555122051) :  사진을 지워버렸네요 ㅠㅜ 서비스 막국수 너무 잘 먹었구요 족발 먹고싶을때마다 여기서 잘 먹고 있어요!
# 유사리뷰 (755, 0.8927698382621636) :  아...항상 받아서 사진 찍고 리뷰를 쓰려 했지만 비쥬얼과 향에 눈이 돌아가서 허겁지겁 먹느라 글로만 리뷰를 남기네요. 오늘은 와이프의 요청으로 냉채족발 먹었는데 야채도 많고 소스도 맛나서 참 잘먹었습니다. 처음에는 고기양이 적어 보여서 좀 실망했었는데 야채랑 같이 먹으니 전혀 부족함이 없었습니다. No.1 킹갓 전설의레전드! 꽃보다족발 번창하십시오~
# 유사리뷰 (1201, 0.8926349243592977) :  너무맛있게먹어서사진을못찍었어요..ㅠㅠ
# 한입먹고흡입 사진생각이싹사라집니다 존맛탱
# 유사리뷰 (1609, 0.8926021781240135) :  도착하자마자 먹어버려서 사진은 못찍었어요.
# 무말랭이가 조금 쓴거 빼고는 양도 맛도 괜찮았습니다^^ 게다가 친절한 배달원님까지 해서 만족하는 저녁식사였습니다!
# 유사리뷰 (23, 0.8913657421129285) :  맛나게 잘 먹었습니다! 먹다가 못 찍었네요 ㅜ
# 유사리뷰 (921, 0.8903171221427856) :  족발 중자로 시켰는데 양이 많습니다! 둘이서 다 못먹어서 다음날까지 먹었습니다.
# 배가고파서 한입먹고 정신없이 먹느라 사진도 못찍었네요. 다음에 찍어야 겠습니다. 김치도 딱 간맞고 좋습니다!
# 유사리뷰 (1301, 0.8901005549536126) :  먹느라 바빠 매번 사진을 못 찍어요 ㅜㅜ
# 맛있어요~
# 유사리뷰 (1927, 0.8898244367444323) :  생각보다 빨리 왔어요 ㅎㅎ
# 사진찍는걸 까먹어서 먹다가 찍었어요 ㅜㅜ ㅋㅋ
# 소자인데 넉넉하게 먹었어요 ㅎㅎ
# 유사리뷰 (1978, 0.8896460405172076) :  아주 맛있게 먹었습니다!! 흔적따윈 없네요 ㅎㅎ
# 유사리뷰 (1711, 0.8895766307866826) :  도착 하자마자 허겁지겁 먹느라 사진을 못찍었네요 ㅠㅠ
# 일하는 곳에서도 자주 시켜먹다가 주말에도 생각나서 시켜봣습니다 ! 정말 맛있어요 막국수도 진짜 맛있음
# 유사리뷰 (1554, 0.8893592214662375) :  맛있었어요 양도 괜찮았어요 잊고있다가 리뷰를 지금쓰네요 ㅠ 사진을 못찍었는데 술을 너무 많이먹게 하시네요
# 유사리뷰 (1516, 0.8891246798787206) :  리뷰 좋아서 처음 배달 했는데 리뷰가 좋은데는 이유가 있었네요~^^ 맛있게 잘 먹었습니다~
# 맛도 좋고 깔끔하고 만족한 저녁 이었습니다~
# 너무 급히 먹느라 사진을 못 찍었네요ㅠㅠ
# 앞으로도 쭈욱~ 변치않는 맛 유지 해주시길~
# 유사리뷰 (331, 0.8881239745354448) :  아차차~!정신없이 먹느라 사진찍는거 깜빡~!!
# 이동네...맛나는 족발집 없었는데~!
# 이제부터 족발은 이집입니다~^-^
# 잘 먹었습니다
# 유사리뷰 (480, 0.8877362607141598) :  다 먹어 버려서 사진은 없지만
# 성x구 살면서 제일 맛있게 먹는집입니다.!
# 이번에도 정말 맛있게 먹었어요!
# 유사리뷰 (1309, 0.8860113350510277) :  사진을 분명히 찍었는데 술김에 지운거 같아요ㅜ
# 근데 족발 보쌈 너무맛있습니다ㅎ
# 특히 막국수 너무 맛있어요
# 여기서만 시켜먹습니다^^
# 유사리뷰 (1279, 0.8859669688117137) :  ㅠ 애들이  너무배고파  사진을 못찍었어요 보쌈 특대 시켰는데
# 양이좀 적네?  했는데 중딩애들 셋이 배부르게 먹었네요^^
# 아주 싹쓸 했습니다  너무 맛있다고  다음에도 요기서 시켜달라네요 ㅎㅎㅎ
# 유사리뷰 (897, 0.8856280434195153) :  비오는날이라 배달시키기 죄송했는데
#
# 암튼 여기는 족발 야들야들 쫀득쫀득
#
# 변함없이 맛있습니다
#
# 막국수도 거의 미친맛 (막국수 서비스 감사합니다)
#
# 미친듯이 먹다가 사진을 늦게찍었네요 ㅜㅜ
# 유사리뷰 (643, 0.8853532232352185) :  정신없이먹느랴 사진을 깜빡했네요 맛있게 잘먹었습니다 또시킬께요!
# 유사리뷰 (1532, 0.884945012535193) :  비오는날 이어서 배달은 조금 늦었지만
# 처음 봉투를 여는순간 양에 한번 놀라고
# 사진을 찍으며 군침을 삼키다가 족발을 먹는순간
# 크으으으 너무 맛있어서 사장님 생각이 절로 나네요
# 맛있게 잘먹었습니다!!
# 유사리뷰 (102, 0.8845578301318183) :  그냥 다른말필요없이 맛있네요
# 양도 부족하지도않고 마스크에 막국수까지
# 구성도좋네요.
# 사진을 못찍어서 죄송합니다.
# 다음에 주문할때는 꼭 사진리뷰하겠습니다
# 유사리뷰 (884, 0.8838845042526816) :  사진을ㅈ못찍었는데 맛있게 잘먹었습니다
# 유사리뷰 (2024, 0.8838579129464553) :  가격도 합리적이고 구성도 알자고
# 넘 맛있었어요~~ 리뷰남기는거 귀찮아서 잘 안하는데 여긴 맛있어서 리뷰남깁니다^^!
#
# 불족발 작은거시켰구요~  족발에 쟁반국수까지 주니 두명에서 충분히 배불리먹을수있었어요!
#
# 맛에 비하여 사진을 너무 못 찍었네요ㅜㅠ
# 암튼 재주문100% 입니다~~^^
# 유사리뷰 (706, 0.8836358939382385) :  너무 맛있어서 먹다가 찍었네요~!!

# %%
cnt=0
a=[]
for i in range(len(cosine_similarities)):
    threshold_num=sum(cosine_similarities[i] > 0.85)
    a.append(threshold_num)

# %%
a=np.array(a)
sum(a>30)
# Out:
# 1556

# %%
a[a>30]
# Out:
# array([752,  51, 465, ..., 283, 765, 501])

# %%
i=1
sum(cosine_similarities[i] > 0.8)
# Out:
# 336

# %%
b=np.array
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-178-a8cb1af2dca5> in <module>
# ----> 1 b=np.array()
#
# TypeError: array() missing required argument 'object' (pos 1)

# %%
a[0]=0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-158-c68d42eb783e> in <module>
# ----> 1 a[0]=0
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed

# %%
b=np.append(b,1)

# %%
b
# Out:
# array([<built-in function array>, 1], dtype=object)
